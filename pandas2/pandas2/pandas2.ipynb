# %%
import requests
import pandas as pd
from io import StringIO

url = 'https://raw.githubusercontent.com/KeithGalli/complete-pandas-tutorial/refs/heads/master/warmup-data/coffee.csv'
response = requests.get(url)
data2 = pd.read_csv(StringIO(response.text))

# %%
data2
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
print(data2)
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
display(data2)
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
data2.sample(10)
# Out:
#           Day Coffee Type  Units Sold
# 10   Saturday    Espresso          45
# 1      Monday       Latte          15
# 13     Sunday       Latte          35
# 4   Wednesday    Espresso          35
# 2     Tuesday    Espresso          30
# 11   Saturday       Latte          35
# 7    Thursday       Latte          30
# 9      Friday       Latte          35
# 0      Monday    Espresso          25
# 5   Wednesday       Latte          25

# %%
data2.sample(10)
# Out:
#           Day Coffee Type  Units Sold
# 4   Wednesday    Espresso          35
# 3     Tuesday       Latte          20
# 6    Thursday    Espresso          40
# 5   Wednesday       Latte          25
# 8      Friday    Espresso          45
# 12     Sunday    Espresso          45
# 0      Monday    Espresso          25
# 10   Saturday    Espresso          45
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30

# %%
data2.sample(10, random_state=1)
# Out:
#           Day Coffee Type  Units Sold
# 3     Tuesday       Latte          20
# 7    Thursday       Latte          30
# 6    Thursday    Espresso          40
# 2     Tuesday    Espresso          30
# 10   Saturday    Espresso          45
# 4   Wednesday    Espresso          35
# 1      Monday       Latte          15
# 12     Sunday    Espresso          45
# 0      Monday    Espresso          25
# 13     Sunday       Latte          35

# %%
data2.loc[3:6,"Day"]
# Out:
# 3      Tuesday
# 4    Wednesday
# 5    Wednesday
# 6     Thursday
# Name: Day, dtype: object

# %%
data2.loc[3:6,["Day","Units Sold" ]]
# Out:
#          Day  Units Sold
# 3    Tuesday          20
# 4  Wednesday          35
# 5  Wednesday          25
# 6   Thursday          40

# %%
data2.loc['Monday']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 data2.loc['Monday']
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/indexing.py:1431, in _LocIndexer._getitem_axis(self, key, axis)
#    1429 # fall thru to straight lookup
#    1430 self._validate_key(key, axis)
# -> 1431 return self._get_label(key, axis=axis)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/indexing.py:1381, in _LocIndexer._get_label(self, label, axis)
#    1379 def _get_label(self, label, axis: AxisInt):
#    1380     # GH#5567 this will fail if the label is not present in the axis.
# -> 1381     return self.obj.xs(label, axis=axis)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/generic.py:4301, in NDFrame.xs(self, key, axis, level, drop_level)
#    4299             new_index = index[loc]
#    4300 else:
# -> 4301     loc = index.get_loc(key)
#    4303     if isinstance(loc, np.ndarray):
#    4304         if loc.dtype == np.bool_:
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/indexes/range.py:417, in RangeIndex.get_loc(self, key)
#     415         raise KeyError(key) from err
#     416 if isinstance(key, Hashable):
# --> 417     raise KeyError(key)
#     418 self._check_indexing_error(key)
#     419 raise KeyError(key)
#
# KeyError: 'Monday'

# %%
data2
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
data2.loc[2,"Units Sold"]=3

# %%
data2
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso           3
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
data2.loc[2:5,"Units Sold"]=3

# %%
data2
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso           3
# 3     Tuesday       Latte           3
# 4   Wednesday    Espresso           3
# 5   Wednesday       Latte           3
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
data2.at[2,"Units Sold"]
# Out:
# np.int64(3)

# %%
data2.iat[2,"Units Sold"]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 data2.iat[2,"Units Sold"]
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/indexing.py:2526, in _ScalarAccessIndexer.__getitem__(self, key)
#    2523     else:
#    2524         raise ValueError("Invalid call for scalar access (getting)!")
# -> 2526 key = self._convert_key(key)
#    2527 return self.obj._get_value(*key, takeable=self._takeable)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/indexing.py:2599, in _iAtIndexer._convert_key(self, key)
#    2597 for i in key:
#    2598     if not is_integer(i):
# -> 2599         raise ValueError("iAt based indexing can only have integer indexers")
#    2600 return key
#
# ValueError: iAt based indexing can only have integer indexers

# %%
data2.iat[2,2]
# Out:
# np.int64(3)

# %%
data2.iat[2,0]
# Out:
# 'Tuesday'

# %%
data2.iat[2,0:1]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 data2.iat[2,0:1]
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/indexing.py:2526, in _ScalarAccessIndexer.__getitem__(self, key)
#    2523     else:
#    2524         raise ValueError("Invalid call for scalar access (getting)!")
# -> 2526 key = self._convert_key(key)
#    2527 return self.obj._get_value(*key, takeable=self._takeable)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/indexing.py:2599, in _iAtIndexer._convert_key(self, key)
#    2597 for i in key:
#    2598     if not is_integer(i):
# -> 2599         raise ValueError("iAt based indexing can only have integer indexers")
#    2600 return key
#
# ValueError: iAt based indexing can only have integer indexers

# %%
data2.iloc[2,0]
# Out:
# 'Tuesday'

# %%
data2.iloc[2,0:2]
# Out:
# Day             Tuesday
# Coffee Type    Espresso
# Name: 2, dtype: object

# %%
data2["Day"]
# Out:
# 0        Monday
# 1        Monday
# 2       Tuesday
# 3       Tuesday
# 4     Wednesday
# 5     Wednesday
# 6      Thursday
# 7      Thursday
# 8        Friday
# 9        Friday
# 10     Saturday
# 11     Saturday
# 12       Sunday
# 13       Sunday
# Name: Day, dtype: object

# %%
data2.Day
# Out:
# 0        Monday
# 1        Monday
# 2       Tuesday
# 3       Tuesday
# 4     Wednesday
# 5     Wednesday
# 6      Thursday
# 7      Thursday
# 8        Friday
# 9        Friday
# 10     Saturday
# 11     Saturday
# 12       Sunday
# 13       Sunday
# Name: Day, dtype: object

# %%
data2["Units Sold"]
# Out:
# 0     25
# 1     15
# 2      3
# 3      3
# 4      3
# 5      3
# 6     40
# 7     30
# 8     45
# 9     35
# 10    45
# 11    35
# 12    45
# 13    35
# Name: Units Sold, dtype: int64

# %%
data2.sort_values["Units Sold"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 data2.sort_values["Units Sold"]
#
# TypeError: 'method' object is not subscriptable

# %%
data2.sort_values("Units Sold")
# Out:
#           Day Coffee Type  Units Sold
# 2     Tuesday    Espresso           3
# 3     Tuesday       Latte           3
# 4   Wednesday    Espresso           3
# 5   Wednesday       Latte           3
# 1      Monday       Latte          15
# 0      Monday    Espresso          25
# 7    Thursday       Latte          30
# 9      Friday       Latte          35
# 11   Saturday       Latte          35
# 13     Sunday       Latte          35
# 6    Thursday    Espresso          40
# 8      Friday    Espresso          45
# 10   Saturday    Espresso          45
# 12     Sunday    Espresso          45

# %%
for index, row in data2.iterrows()
# Out:
#   Cell In[39], line 1
#     for index, row in data2.iterrows()
#                                       ^
# SyntaxError: expected ':'

# %%
for index, row in data2.iterrows():
# Out:
#   Cell In[40], line 2
#
#     ^
# _IncompleteInputError: incomplete input

# %%
for index, row in data2.iterrows():
    index

# %%
index
# Out:
# 13

# %%
for index, row in data2.iterrows():
    print(index)
    print(row)
    print("\n\n")
# Out:
# 0
# Day              Monday
# Coffee Type    Espresso
# Units Sold           25
# Name: 0, dtype: object
#
#
#
# 1
# Day            Monday
# Coffee Type     Latte
# Units Sold         15
# Name: 1, dtype: object
#
#
#
# 2
# Day             Tuesday
# Coffee Type    Espresso
# Units Sold            3
# Name: 2, dtype: object
#
#
#
# 3
# Day            Tuesday
# Coffee Type      Latte
# Units Sold           3
# Name: 3, dtype: object
#
#
#
# 4
# Day            Wednesday
# Coffee Type     Espresso
# Units Sold             3
# Name: 4, dtype: object
#
#
#
# 5
# Day            Wednesday
# Coffee Type        Latte
# Units Sold             3
# Name: 5, dtype: object
#
#
#
# 6
# Day            Thursday
# Coffee Type    Espresso
# Units Sold           40
# Name: 6, dtype: object
#
#
#
# 7
# Day            Thursday
# Coffee Type       Latte
# Units Sold           30
# Name: 7, dtype: object
#
#
#
# 8
# Day              Friday
# Coffee Type    Espresso
# Units Sold           45
# Name: 8, dtype: object
#
#
#
# 9
# Day            Friday
# Coffee Type     Latte
# Units Sold         35
# Name: 9, dtype: object
#
#
#
# 10
# Day            Saturday
# Coffee Type    Espresso
# Units Sold           45
# Name: 10, dtype: object
#
#
#
# 11
# Day            Saturday
# Coffee Type       Latte
# Units Sold           35
# Name: 11, dtype: object
#
#
#
# 12
# Day              Sunday
# Coffee Type    Espresso
# Units Sold           45
# Name: 12, dtype: object
#
#
#
# 13
# Day            Sunday
# Coffee Type     Latte
# Units Sold         35
# Name: 13, dtype: object

# %%
data3=pd.read_feather('results.feather')

# %%
data3
# Out:
#           year    type              discipline                          event  \
# 0       1912.0  Summer                  Tennis         Singles, Men (Olympic)
# 1       1912.0  Summer                  Tennis         Doubles, Men (Olympic)
# 2       1920.0  Summer                  Tennis         Singles, Men (Olympic)
# 3       1920.0  Summer                  Tennis       Doubles, Mixed (Olympic)
# 4       1920.0  Summer                  Tennis         Doubles, Men (Olympic)
# ...        ...     ...                     ...                            ...
# 308403  2022.0  Winter                    Luge         Singles, Men (Olympic)
# 308404  2022.0  Winter  Alpine Skiing (Skiing)        Slalom, Women (Olympic)
# 308405  2022.0  Winter  Alpine Skiing (Skiing)          Team, Mixed (Olympic)
# 308406  2022.0  Winter  Alpine Skiing (Skiing)  Giant Slalom, Women (Olympic)
# 308407  2022.0  Winter                    None        Slalom, Women (Olympic)
#
#                            as  athlete_id   noc             team  place  \
# 0       Jean-François Blanchy           1   FRA             None   17.0
# 1       Jean-François Blanchy           1   FRA   Jean Montariol    NaN
# 2       Jean-François Blanchy           1   FRA             None   32.0
# 3       Jean-François Blanchy           1   FRA  Jeanne Vaussard    8.0
# 4       Jean-François Blanchy           1   FRA  Jacques Brugnon    4.0
# ...                       ...         ...   ...              ...    ...
# 308403          Marián Skupek      148983   SVK             None   26.0
# 308404          Elsa Fermbäck      148984   SWE             None   28.0
# 308405          Hilma Lövblom      148985   SWE           Sweden   13.0
# 308406          Hilma Lövblom      148985   SWE             None    NaN
# 308407   Charlotta Säfvenberg      148986  None             None   24.0
#
#          tied medal
# 0        True  None
# 1       False  None
# 2        True  None
# 3        True  None
# 4       False  None
# ...       ...   ...
# 308403  False  None
# 308404  False  None
# 308405  False  None
# 308406  False  None
# 308407  False  None
#
# [308408 rows x 11 columns]

# %%
data4=pd.read_parquet('results.parquet')

# %%
data4
# Out:
#           year    type              discipline                          event  \
# 0       1912.0  Summer                  Tennis         Singles, Men (Olympic)
# 1       1912.0  Summer                  Tennis         Doubles, Men (Olympic)
# 2       1920.0  Summer                  Tennis         Singles, Men (Olympic)
# 3       1920.0  Summer                  Tennis       Doubles, Mixed (Olympic)
# 4       1920.0  Summer                  Tennis         Doubles, Men (Olympic)
# ...        ...     ...                     ...                            ...
# 308403  2022.0  Winter                    Luge         Singles, Men (Olympic)
# 308404  2022.0  Winter  Alpine Skiing (Skiing)        Slalom, Women (Olympic)
# 308405  2022.0  Winter  Alpine Skiing (Skiing)          Team, Mixed (Olympic)
# 308406  2022.0  Winter  Alpine Skiing (Skiing)  Giant Slalom, Women (Olympic)
# 308407  2022.0  Winter                    None        Slalom, Women (Olympic)
#
#                            as  athlete_id   noc             team  place  \
# 0       Jean-François Blanchy           1   FRA             None   17.0
# 1       Jean-François Blanchy           1   FRA   Jean Montariol    NaN
# 2       Jean-François Blanchy           1   FRA             None   32.0
# 3       Jean-François Blanchy           1   FRA  Jeanne Vaussard    8.0
# 4       Jean-François Blanchy           1   FRA  Jacques Brugnon    4.0
# ...                       ...         ...   ...              ...    ...
# 308403          Marián Skupek      148983   SVK             None   26.0
# 308404          Elsa Fermbäck      148984   SWE             None   28.0
# 308405          Hilma Lövblom      148985   SWE           Sweden   13.0
# 308406          Hilma Lövblom      148985   SWE             None    NaN
# 308407   Charlotta Säfvenberg      148986  None             None   24.0
#
#          tied medal
# 0        True  None
# 1       False  None
# 2        True  None
# 3        True  None
# 4       False  None
# ...       ...   ...
# 308403  False  None
# 308404  False  None
# 308405  False  None
# 308406  False  None
# 308407  False  None
#
# [308408 rows x 11 columns]

# %%
data4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 308408 entries, 0 to 308407
# Data columns (total 11 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   year        305807 non-null  float64
#  1   type        305807 non-null  object
#  2   discipline  308407 non-null  object
#  3   event       308408 non-null  object
#  4   as          308408 non-null  object
#  5   athlete_id  308408 non-null  int64
#  6   noc         308407 non-null  object
#  7   team        121714 non-null  object
#  8   place       283193 non-null  float64
#  9   tied        308408 non-null  bool
#  10  medal       44139 non-null   object
# dtypes: bool(1), float64(2), int64(1), object(7)
# memory usage: 23.8+ MB

# %%
data4[data4['place']>24]
# Out:
#           year    type                     discipline  \
# 2       1920.0  Summer                         Tennis
# 16      1992.0  Summer                   Table Tennis
# 23      2008.0  Summer                   Table Tennis
# 60      2008.0  Summer                   Table Tennis
# 68      1988.0  Summer                   Table Tennis
# ...        ...     ...                            ...
# 308383  2022.0  Winter                       Biathlon
# 308385  2022.0  Winter  Cross Country Skiing (Skiing)
# 308386  2022.0  Winter  Cross Country Skiing (Skiing)
# 308403  2022.0  Winter                           Luge
# 308404  2022.0  Winter         Alpine Skiing (Skiing)
#
#                                          event                     as  \
# 2                       Singles, Men (Olympic)  Jean-François Blanchy
# 16                      Singles, Men (Olympic)      Nicolas Chatelain
# 23                      Singles, Men (Olympic)          Patrick Chila
# 60                      Singles, Men (Olympic)            Damien Éloi
# 68                      Singles, Men (Olympic)   Jean-Philippe Gatien
# ...                                        ...                    ...
# 308383            20 kilometres, Men (Olympic)        Tomáš Sklenárik
# 308385            50 kilometres, Men (Olympic)           Ján Koristek
# 308386  30 kilometres Skiathlon, Men (Olympic)           Ján Koristek
# 308403                  Singles, Men (Olympic)          Marián Skupek
# 308404                 Slalom, Women (Olympic)          Elsa Fermbäck
#
#         athlete_id  noc  team  place   tied medal
# 2                1  FRA  None   32.0   True  None
# 16               6  FRA  None   33.0   True  None
# 23               7  FRA  None   49.0   True  None
# 60              15  FRA  None   33.0   True  None
# 68              18  FRA  None   33.0   True  None
# ...            ...  ...   ...    ...    ...   ...
# 308383      148964  SVK  None   80.0  False  None
# 308385      148965  SVK  None   40.0  False  None
# 308386      148965  SVK  None   45.0  False  None
# 308403      148983  SVK  None   26.0  False  None
# 308404      148984  SWE  None   28.0  False  None
#
# [56430 rows x 11 columns]

# %%
data4[data4['place']>24]['discipline','type']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('discipline', 'type')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 data4[data4['place']>24]['discipline','type']
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: ('discipline', 'type')

# %%
data4[data4['place']>24][['discipline','type']]
# Out:
#                            discipline    type
# 2                              Tennis  Summer
# 16                       Table Tennis  Summer
# 23                       Table Tennis  Summer
# 60                       Table Tennis  Summer
# 68                       Table Tennis  Summer
# ...                               ...     ...
# 308383                       Biathlon  Winter
# 308385  Cross Country Skiing (Skiing)  Winter
# 308386  Cross Country Skiing (Skiing)  Winter
# 308403                           Luge  Winter
# 308404         Alpine Skiing (Skiing)  Winter
#
# [56430 rows x 2 columns]

# %%
data4[data4['place']>24,['discipline','type']]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:173, in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(0         False
# 1         False
# 2          True
# 3         False
# 4         False
#           ...
# 308403     True
# 308404     True
# 308405    False
# 308406    False
# 308407    False
# Name: place, Length: 308408, dtype: bool, ['discipline', 'type'])' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 data4[data4['place']>24,['discipline','type']]
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/indexes/base.py:3817, in Index.get_loc(self, key)
#    3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
# -> 3817     self._check_indexing_error(key)
#    3818     raise
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/indexes/base.py:6059, in Index._check_indexing_error(self, key)
#    6055 def _check_indexing_error(self, key):
#    6056     if not is_scalar(key):
#    6057         # if key is not a scalar, directly raise an error (the code below
#    6058         # would convert to numpy arrays and raise later any way) - GH29926
# -> 6059         raise InvalidIndexError(key)
#
# InvalidIndexError: (0         False
# 1         False
# 2          True
# 3         False
# 4         False
#           ...
# 308403     True
# 308404     True
# 308405    False
# 308406    False
# 308407    False
# Name: place, Length: 308408, dtype: bool, ['discipline', 'type'])

# %%
 data4[data4['discipline'].str.contains("Biathlon")]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 data4[data4['discipline'].str.contains("Biathlon")]
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/frame.py:4092, in DataFrame.__getitem__(self, key)
#    4089     return self.where(key)
#    4091 # Do we have a (boolean) 1d indexer?
# -> 4092 if com.is_bool_indexer(key):
#    4093     return self._getitem_bool_array(key)
#    4095 # We are left with two options: a single key, and a collection of keys,
#    4096 # We interpret tuples as collections only for non-MultiIndex
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/common.py:136, in is_bool_indexer(key)
#     132     na_msg = "Cannot mask with non-boolean array containing NA / NaN values"
#     133     if lib.is_bool_array(key_array, skipna=True):
#     134         # Don't raise on e.g. ["A", "B", np.nan], see
#     135         #  test_loc_getitem_list_of_labels_categoricalindex_with_na
# --> 136         raise ValueError(na_msg)
#     137     return False
#     138 return True
#
# ValueError: Cannot mask with non-boolean array containing NA / NaN values

# %%
 data4[data4['discipline']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 data4[data4['discipline']]
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/indexes/base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/indexes/base.py:6249, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6247 if nmissing:
#    6248     if nmissing == len(indexer):
# -> 6249         raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251     not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6252     raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index([                 'Tennis',                  'Tennis',\n                        'Tennis',                  'Tennis',\n                        'Tennis',                  'Tennis',\n                        'Tennis',                  'Tennis',\n                        'Tennis',                  'Tennis',\n       ...\n       'Ice Hockey (Ice Hockey)', 'Ice Hockey (Ice Hockey)',\n       'Ice Hockey (Ice Hockey)', 'Ice Hockey (Ice Hockey)',\n       'Ice Hockey (Ice Hockey)',                    'Luge',\n        'Alpine Skiing (Skiing)',  'Alpine Skiing (Skiing)',\n        'Alpine Skiing (Skiing)',                      None],\n      dtype='object', length=308408)] are in the [columns]"

# %%
data4.loc[data4['place'] > 24, ['discipline', 'type']]
# Out:
#                            discipline    type
# 2                              Tennis  Summer
# 16                       Table Tennis  Summer
# 23                       Table Tennis  Summer
# 60                       Table Tennis  Summer
# 68                       Table Tennis  Summer
# ...                               ...     ...
# 308383                       Biathlon  Winter
# 308385  Cross Country Skiing (Skiing)  Winter
# 308386  Cross Country Skiing (Skiing)  Winter
# 308403                           Luge  Winter
# 308404         Alpine Skiing (Skiing)  Winter
#
# [56430 rows x 2 columns]

# %%
data4[data4['discipline']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 data4[data4['discipline']]
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/indexes/base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/indexes/base.py:6249, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6247 if nmissing:
#    6248     if nmissing == len(indexer):
# -> 6249         raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251     not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6252     raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index([                 'Tennis',                  'Tennis',\n                        'Tennis',                  'Tennis',\n                        'Tennis',                  'Tennis',\n                        'Tennis',                  'Tennis',\n                        'Tennis',                  'Tennis',\n       ...\n       'Ice Hockey (Ice Hockey)', 'Ice Hockey (Ice Hockey)',\n       'Ice Hockey (Ice Hockey)', 'Ice Hockey (Ice Hockey)',\n       'Ice Hockey (Ice Hockey)',                    'Luge',\n        'Alpine Skiing (Skiing)',  'Alpine Skiing (Skiing)',\n        'Alpine Skiing (Skiing)',                      None],\n      dtype='object', length=308408)] are in the [columns]"

# %%
print(data4['discipline'])
# Out:
# 0                         Tennis
# 1                         Tennis
# 2                         Tennis
# 3                         Tennis
# 4                         Tennis
#                    ...
# 308403                      Luge
# 308404    Alpine Skiing (Skiing)
# 308405    Alpine Skiing (Skiing)
# 308406    Alpine Skiing (Skiing)
# 308407                      None
# Name: discipline, Length: 308408, dtype: object

# %%
data4[data4['discipline'].astype(str).str.contains("Biathlon", na=False)]
# Out:
#           year    type discipline  \
# 141533  1964.0  Winter   Biathlon
# 168142  1992.0  Winter   Biathlon
# 168143  1992.0  Winter   Biathlon
# 168144  1992.0  Winter   Biathlon
# 168145  1994.0  Winter   Biathlon
# ...        ...     ...        ...
# 308380  2022.0  Winter   Biathlon
# 308381  2022.0  Winter   Biathlon
# 308382  2022.0  Winter   Biathlon
# 308383  2022.0  Winter   Biathlon
# 308384  2022.0  Winter   Biathlon
#
#                                                     event                 as  \
# 141533                       20 kilometres, Men (Olympic)        Hannu Posti
# 168142             7.5 kilometres Sprint, Women (Olympic)  Jiřína Adamičková
# 168143                     15 kilometres, Women (Olympic)  Jiřína Adamičková
# 168144          3 × 7.5 kilometres Relay, Women (Olympic)  Jiřína Adamičková
# 168145             7.5 kilometres Sprint, Women (Olympic)     Jiřína Pelcová
# ...                                                   ...                ...
# 308380            4 × 7.5 kilometres Relay, Men (Olympic)       Matej Baloga
# 308381                10 kilometres Sprint, Men (Olympic)    Tomáš Sklenárik
# 308382  2 × 6 kilometres and 2 × 7.5 kilometres Relay,...    Tomáš Sklenárik
# 308383                       20 kilometres, Men (Olympic)    Tomáš Sklenárik
# 308384            4 × 7.5 kilometres Relay, Men (Olympic)    Tomáš Sklenárik
#
#         athlete_id  noc            team  place   tied medal
# 141533       67751  FIN            None    8.0  False  None
# 168142       80509  TCH            None    5.0  False  None
# 168143       80509  TCH            None   23.0  False  None
# 168144       80509  TCH  Czechoslovakia    8.0  False  None
# 168145       80509  CZE            None   49.0  False  None
# ...            ...  ...             ...    ...    ...   ...
# 308380      148963  SVK        Slovakia   21.0  False  None
# 308381      148964  SVK            None   87.0  False  None
# 308382      148964  SVK        Slovakia   17.0  False  None
# 308383      148964  SVK            None   80.0  False  None
# 308384      148964  SVK        Slovakia   21.0  False  None
#
# [7138 rows x 11 columns]

# %%
data4[data4['discipline'].astype(str).str.contains("Biathlon|Tennis", na=False)]
# Out:
#           year    type discipline  \
# 0       1912.0  Summer     Tennis
# 1       1912.0  Summer     Tennis
# 2       1920.0  Summer     Tennis
# 3       1920.0  Summer     Tennis
# 4       1920.0  Summer     Tennis
# ...        ...     ...        ...
# 308380  2022.0  Winter   Biathlon
# 308381  2022.0  Winter   Biathlon
# 308382  2022.0  Winter   Biathlon
# 308383  2022.0  Winter   Biathlon
# 308384  2022.0  Winter   Biathlon
#
#                                                     event  \
# 0                                  Singles, Men (Olympic)
# 1                                  Doubles, Men (Olympic)
# 2                                  Singles, Men (Olympic)
# 3                                Doubles, Mixed (Olympic)
# 4                                  Doubles, Men (Olympic)
# ...                                                   ...
# 308380            4 × 7.5 kilometres Relay, Men (Olympic)
# 308381                10 kilometres Sprint, Men (Olympic)
# 308382  2 × 6 kilometres and 2 × 7.5 kilometres Relay,...
# 308383                       20 kilometres, Men (Olympic)
# 308384            4 × 7.5 kilometres Relay, Men (Olympic)
#
#                            as  athlete_id  noc             team  place   tied  \
# 0       Jean-François Blanchy           1  FRA             None   17.0   True
# 1       Jean-François Blanchy           1  FRA   Jean Montariol    NaN  False
# 2       Jean-François Blanchy           1  FRA             None   32.0   True
# 3       Jean-François Blanchy           1  FRA  Jeanne Vaussard    8.0   True
# 4       Jean-François Blanchy           1  FRA  Jacques Brugnon    4.0  False
# ...                       ...         ...  ...              ...    ...    ...
# 308380           Matej Baloga      148963  SVK         Slovakia   21.0  False
# 308381        Tomáš Sklenárik      148964  SVK             None   87.0  False
# 308382        Tomáš Sklenárik      148964  SVK         Slovakia   17.0  False
# 308383        Tomáš Sklenárik      148964  SVK             None   80.0  False
# 308384        Tomáš Sklenárik      148964  SVK         Slovakia   21.0  False
#
#        medal
# 0       None
# 1       None
# 2       None
# 3       None
# 4       None
# ...      ...
# 308380  None
# 308381  None
# 308382  None
# 308383  None
# 308384  None
#
# [12791 rows x 11 columns]

# %%
data4.query("discipline.str.contains('Biathlon', na=False)", engine="python")
# Out:
#           year    type discipline  \
# 141533  1964.0  Winter   Biathlon
# 168142  1992.0  Winter   Biathlon
# 168143  1992.0  Winter   Biathlon
# 168144  1992.0  Winter   Biathlon
# 168145  1994.0  Winter   Biathlon
# ...        ...     ...        ...
# 308380  2022.0  Winter   Biathlon
# 308381  2022.0  Winter   Biathlon
# 308382  2022.0  Winter   Biathlon
# 308383  2022.0  Winter   Biathlon
# 308384  2022.0  Winter   Biathlon
#
#                                                     event                 as  \
# 141533                       20 kilometres, Men (Olympic)        Hannu Posti
# 168142             7.5 kilometres Sprint, Women (Olympic)  Jiřína Adamičková
# 168143                     15 kilometres, Women (Olympic)  Jiřína Adamičková
# 168144          3 × 7.5 kilometres Relay, Women (Olympic)  Jiřína Adamičková
# 168145             7.5 kilometres Sprint, Women (Olympic)     Jiřína Pelcová
# ...                                                   ...                ...
# 308380            4 × 7.5 kilometres Relay, Men (Olympic)       Matej Baloga
# 308381                10 kilometres Sprint, Men (Olympic)    Tomáš Sklenárik
# 308382  2 × 6 kilometres and 2 × 7.5 kilometres Relay,...    Tomáš Sklenárik
# 308383                       20 kilometres, Men (Olympic)    Tomáš Sklenárik
# 308384            4 × 7.5 kilometres Relay, Men (Olympic)    Tomáš Sklenárik
#
#         athlete_id  noc            team  place   tied medal
# 141533       67751  FIN            None    8.0  False  None
# 168142       80509  TCH            None    5.0  False  None
# 168143       80509  TCH            None   23.0  False  None
# 168144       80509  TCH  Czechoslovakia    8.0  False  None
# 168145       80509  CZE            None   49.0  False  None
# ...            ...  ...             ...    ...    ...   ...
# 308380      148963  SVK        Slovakia   21.0  False  None
# 308381      148964  SVK            None   87.0  False  None
# 308382      148964  SVK        Slovakia   17.0  False  None
# 308383      148964  SVK            None   80.0  False  None
# 308384      148964  SVK        Slovakia   21.0  False  None
#
# [7138 rows x 11 columns]

# %%
data4.query('discipline'=="Tennis")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/tx/8b5nnqtj2pq8dp4pn18b_6rm0000gn/T/ipykernel_48182/2760557480.py in ?()
# ----> 1 data4.query('discipline'=="Tennis")
#
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/frame.py in ?(self, expr, inplace, **kwargs)
#    4816         """
#    4817         inplace = validate_bool_kwarg(inplace, "inplace")
#    4818         if not isinstance(expr, str):
#    4819             msg = f"expr must be a string to be evaluated, {type(expr)} given"
# -> 4820             raise ValueError(msg)
#    4821         kwargs["level"] = kwargs.pop("level", 0) + 1
#    4822         kwargs["target"] = None
#    4823         res = self.eval(expr, **kwargs)
#
# ValueError: expr must be a string to be evaluated, <class 'bool'> given

# %%
data4.query('discipline=="Tennis"')
# Out:
#           year    type discipline                     event  \
# 0       1912.0  Summer     Tennis    Singles, Men (Olympic)
# 1       1912.0  Summer     Tennis    Doubles, Men (Olympic)
# 2       1920.0  Summer     Tennis    Singles, Men (Olympic)
# 3       1920.0  Summer     Tennis  Doubles, Mixed (Olympic)
# 4       1920.0  Summer     Tennis    Doubles, Men (Olympic)
# ...        ...     ...        ...                       ...
# 306308  2020.0  Summer     Tennis  Doubles, Women (Olympic)
# 306309  2020.0  Summer     Tennis  Doubles, Women (Olympic)
# 306310  2020.0  Summer     Tennis  Doubles, Women (Olympic)
# 306311  2020.0  Summer     Tennis  Doubles, Women (Olympic)
# 306312  2020.0  Summer     Tennis  Doubles, Women (Olympic)
#
#                            as  athlete_id  noc             team  place   tied  \
# 0       Jean-François Blanchy           1  FRA             None   17.0   True
# 1       Jean-François Blanchy           1  FRA   Jean Montariol    NaN  False
# 2       Jean-François Blanchy           1  FRA             None   32.0   True
# 3       Jean-François Blanchy           1  FRA  Jeanne Vaussard    8.0   True
# 4       Jean-François Blanchy           1  FRA  Jacques Brugnon    4.0  False
# ...                       ...         ...  ...              ...    ...    ...
# 306308         Hsieh Yu-Chieh      147671  TPE       Connie Hsu   17.0   True
# 306309             Connie Hsu      147672  TPE   Hsieh Yu-Chieh   17.0   True
# 306310         Giuliana Olmos      147673  MEX   Renata Zarazúa   17.0   True
# 306311        Makoto Ninomiya      147674  JPN       Nao Hibino   17.0   True
# 306312          Laura Pigossi      147675  BRA    Luísa Stefani    3.0  False
#
#          medal
# 0         None
# 1         None
# 2         None
# 3         None
# 4         None
# ...        ...
# 306308    None
# 306309    None
# 306310    None
# 306311    None
# 306312  Bronze
#
# [3411 rows x 11 columns]

# %%
data4.query('discipline=="Tennis" and team=="Hibino"')
# Out:
# Empty DataFrame
# Columns: [year, type, discipline, event, as, athlete_id, noc, team, place, tied, medal]
# Index: []

# %%
data4.query('discipline=="Tennis" and type=="Summer"')
# Out:
#           year    type discipline                     event  \
# 0       1912.0  Summer     Tennis    Singles, Men (Olympic)
# 1       1912.0  Summer     Tennis    Doubles, Men (Olympic)
# 2       1920.0  Summer     Tennis    Singles, Men (Olympic)
# 3       1920.0  Summer     Tennis  Doubles, Mixed (Olympic)
# 4       1920.0  Summer     Tennis    Doubles, Men (Olympic)
# ...        ...     ...        ...                       ...
# 306308  2020.0  Summer     Tennis  Doubles, Women (Olympic)
# 306309  2020.0  Summer     Tennis  Doubles, Women (Olympic)
# 306310  2020.0  Summer     Tennis  Doubles, Women (Olympic)
# 306311  2020.0  Summer     Tennis  Doubles, Women (Olympic)
# 306312  2020.0  Summer     Tennis  Doubles, Women (Olympic)
#
#                            as  athlete_id  noc             team  place   tied  \
# 0       Jean-François Blanchy           1  FRA             None   17.0   True
# 1       Jean-François Blanchy           1  FRA   Jean Montariol    NaN  False
# 2       Jean-François Blanchy           1  FRA             None   32.0   True
# 3       Jean-François Blanchy           1  FRA  Jeanne Vaussard    8.0   True
# 4       Jean-François Blanchy           1  FRA  Jacques Brugnon    4.0  False
# ...                       ...         ...  ...              ...    ...    ...
# 306308         Hsieh Yu-Chieh      147671  TPE       Connie Hsu   17.0   True
# 306309             Connie Hsu      147672  TPE   Hsieh Yu-Chieh   17.0   True
# 306310         Giuliana Olmos      147673  MEX   Renata Zarazúa   17.0   True
# 306311        Makoto Ninomiya      147674  JPN       Nao Hibino   17.0   True
# 306312          Laura Pigossi      147675  BRA    Luísa Stefani    3.0  False
#
#          medal
# 0         None
# 1         None
# 2         None
# 3         None
# 4         None
# ...        ...
# 306308    None
# 306309    None
# 306310    None
# 306311    None
# 306312  Bronze
#
# [3360 rows x 11 columns]
