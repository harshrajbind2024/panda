# %%
import pandas as pd

# %%
data=pd.read_csv('bios.csv')

# %%
data.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %%
data.query('born_country=="GBR"')
# Out:
#         athlete_id                name   born_date     born_city born_region  \
# 4                5        Albert Canet  1878-04-17    Wandsworth     England
# 37              38     Helen Aitchison  1881-12-06    Sunderland     England
# 38              39   Geraldine Beamish  1883-06-23   Forest Gate     England
# 39              40        Dora Boothby  1881-08-02      Finchley     England
# 40              41      Julie Bradbury  1967-02-12        Oxford     England
# ...            ...                 ...         ...           ...         ...
# 144811      148512  Benjamin Alexander  1983-05-08        London     England
# 144815      148517       Ashley Watson  1993-10-28  Peterborough     England
# 145005      148716     Peder Kongshaug  2001-08-13     Wimbledon     England
# 145319      149041          Axel Brown  1992-04-02     Harrogate     England
# 145388      149111      Jean-Luc Baker  1993-10-07       Burnley     England
#
#        born_country                  NOC  height_cm  weight_kg   died_date
# 4               GBR               France        NaN        NaN  1930-07-25
# 37              GBR        Great Britain        NaN        NaN  1947-05-26
# 38              GBR        Great Britain        NaN        NaN  1972-05-10
# 39              GBR        Great Britain        NaN        NaN  1970-02-22
# 40              GBR        Great Britain      175.0       64.0         NaN
# ...             ...                  ...        ...        ...         ...
# 144811          GBR              Jamaica        NaN        NaN         NaN
# 144815          GBR              Jamaica        NaN        NaN         NaN
# 145005          GBR               Norway      184.0       86.0         NaN
# 145319          GBR  Trinidad and Tobago        NaN        NaN         NaN
# 145388          GBR        United States        NaN        NaN         NaN
#
# [5792 rows x 10 columns]

# %%
data['price']=4

# %%
data
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# 0                    Gironde          FRA     France        NaN        NaN
# 1                   Yvelines          FRA     France      183.0       76.0
# 2       Pyrénées-Atlantiques          FRA     France      183.0       76.0
# 3                      Paris          FRA     France      168.0       64.0
# 4                    England          GBR     France        NaN        NaN
# ...                      ...          ...        ...        ...        ...
# 145495            Sverdlovsk          RUS        ROC      167.0       61.0
# 145496                Moskva          RUS        ROC      168.0       65.0
# 145497           Arkhangelsk          RUS        ROC      163.0       55.0
# 145498           Deux-Sèvres          FRA     France      166.0        NaN
# 145499       New South Wales          AUS  Australia        NaN        NaN
#
#          died_date  price
# 0       1960-10-02      4
# 1              NaN      4
# 2       1994-07-17      4
# 3       1978-03-20      4
# 4       1930-07-25      4
# ...            ...    ...
# 145495         NaN      4
# 145496         NaN      4
# 145497         NaN      4
# 145498  1986-03-18      4
# 145499  2003-10-20      4
#
# [145500 rows x 11 columns]

# %%
data.drop(1)
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# 5                6      Nicolas Chatelain  1970-01-13           Amiens
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# 0                    Gironde          FRA     France        NaN        NaN
# 2       Pyrénées-Atlantiques          FRA     France      183.0       76.0
# 3                      Paris          FRA     France      168.0       64.0
# 4                    England          GBR     France        NaN        NaN
# 5                      Somme          FRA     France      181.0       70.0
# ...                      ...          ...        ...        ...        ...
# 145495            Sverdlovsk          RUS        ROC      167.0       61.0
# 145496                Moskva          RUS        ROC      168.0       65.0
# 145497           Arkhangelsk          RUS        ROC      163.0       55.0
# 145498           Deux-Sèvres          FRA     France      166.0        NaN
# 145499       New South Wales          AUS  Australia        NaN        NaN
#
#          died_date  price
# 0       1960-10-02      4
# 2       1994-07-17      4
# 3       1978-03-20      4
# 4       1930-07-25      4
# 5              NaN      4
# ...            ...    ...
# 145495         NaN      4
# 145496         NaN      4
# 145497         NaN      4
# 145498  1986-03-18      4
# 145499  2003-10-20      4
#
# [145499 rows x 11 columns]

# %%
data.drop(columns=['price'])
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# 0                    Gironde          FRA     France        NaN        NaN
# 1                   Yvelines          FRA     France      183.0       76.0
# 2       Pyrénées-Atlantiques          FRA     France      183.0       76.0
# 3                      Paris          FRA     France      168.0       64.0
# 4                    England          GBR     France        NaN        NaN
# ...                      ...          ...        ...        ...        ...
# 145495            Sverdlovsk          RUS        ROC      167.0       61.0
# 145496                Moskva          RUS        ROC      168.0       65.0
# 145497           Arkhangelsk          RUS        ROC      163.0       55.0
# 145498           Deux-Sèvres          FRA     France      166.0        NaN
# 145499       New South Wales          AUS  Australia        NaN        NaN
#
#          died_date
# 0       1960-10-02
# 1              NaN
# 2       1994-07-17
# 3       1978-03-20
# 4       1930-07-25
# ...            ...
# 145495         NaN
# 145496         NaN
# 145497         NaN
# 145498  1986-03-18
# 145499  2003-10-20
#
# [145500 rows x 10 columns]

# %%
data1=data[['born_city','born_country','born_region']]

# %%
data1
# Out:
#               born_city born_country           born_region
# 0              Bordeaux          FRA               Gironde
# 1                Meulan          FRA              Yvelines
# 2              Biarritz          FRA  Pyrénées-Atlantiques
# 3           Paris VIIIe          FRA                 Paris
# 4            Wandsworth          GBR               England
# ...                 ...          ...                   ...
# 145495            Serov          RUS            Sverdlovsk
# 145496  Moskva (Moscow)          RUS                Moskva
# 145497           Kotlas          RUS           Arkhangelsk
# 145498            Niort          FRA           Deux-Sèvres
# 145499     Dulwich Hill          AUS       New South Wales
#
# [145500 rows x 3 columns]

# %%
data1.rename(columns={'born_city':'b_city'})
# Out:
#                  b_city born_country           born_region
# 0              Bordeaux          FRA               Gironde
# 1                Meulan          FRA              Yvelines
# 2              Biarritz          FRA  Pyrénées-Atlantiques
# 3           Paris VIIIe          FRA                 Paris
# 4            Wandsworth          GBR               England
# ...                 ...          ...                   ...
# 145495            Serov          RUS            Sverdlovsk
# 145496  Moskva (Moscow)          RUS                Moskva
# 145497           Kotlas          RUS           Arkhangelsk
# 145498            Niort          FRA           Deux-Sèvres
# 145499     Dulwich Hill          AUS       New South Wales
#
# [145500 rows x 3 columns]

# %%
data1
# Out:
#               born_city born_country           born_region
# 0              Bordeaux          FRA               Gironde
# 1                Meulan          FRA              Yvelines
# 2              Biarritz          FRA  Pyrénées-Atlantiques
# 3           Paris VIIIe          FRA                 Paris
# 4            Wandsworth          GBR               England
# ...                 ...          ...                   ...
# 145495            Serov          RUS            Sverdlovsk
# 145496  Moskva (Moscow)          RUS                Moskva
# 145497           Kotlas          RUS           Arkhangelsk
# 145498            Niort          FRA           Deux-Sèvres
# 145499     Dulwich Hill          AUS       New South Wales
#
# [145500 rows x 3 columns]

# %%
data1.rename(columns={'b_city':'bn_city'}, inplace=True)

# %%
data1
# Out:
#                 bn_city born_country           born_region
# 0              Bordeaux          FRA               Gironde
# 1                Meulan          FRA              Yvelines
# 2              Biarritz          FRA  Pyrénées-Atlantiques
# 3           Paris VIIIe          FRA                 Paris
# 4            Wandsworth          GBR               England
# ...                 ...          ...                   ...
# 145495            Serov          RUS            Sverdlovsk
# 145496  Moskva (Moscow)          RUS                Moskva
# 145497           Kotlas          RUS           Arkhangelsk
# 145498            Niort          FRA           Deux-Sèvres
# 145499     Dulwich Hill          AUS       New South Wales
#
# [145500 rows x 3 columns]

# %%
data1
# Out:
#                 bn_city born_country           born_region
# 0              Bordeaux          FRA               Gironde
# 1                Meulan          FRA              Yvelines
# 2              Biarritz          FRA  Pyrénées-Atlantiques
# 3           Paris VIIIe          FRA                 Paris
# 4            Wandsworth          GBR               England
# ...                 ...          ...                   ...
# 145495            Serov          RUS            Sverdlovsk
# 145496  Moskva (Moscow)          RUS                Moskva
# 145497           Kotlas          RUS           Arkhangelsk
# 145498            Niort          FRA           Deux-Sèvres
# 145499     Dulwich Hill          AUS       New South Wales
#
# [145500 rows x 3 columns]

# %%
data
# Out:
#               born_city born_country           born_region
# 0              Bordeaux          FRA               Gironde
# 1                Meulan          FRA              Yvelines
# 2              Biarritz          FRA  Pyrénées-Atlantiques
# 3           Paris VIIIe          FRA                 Paris
# 4            Wandsworth          GBR               England
# ...                 ...          ...                   ...
# 145495            Serov          RUS            Sverdlovsk
# 145496  Moskva (Moscow)          RUS                Moskva
# 145497           Kotlas          RUS           Arkhangelsk
# 145498            Niort          FRA           Deux-Sèvres
# 145499     Dulwich Hill          AUS       New South Wales
#
# [145500 rows x 3 columns]

# %%
data=pd.read_csv('bios.csv')

# %%
data
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# 0                    Gironde          FRA     France        NaN        NaN
# 1                   Yvelines          FRA     France      183.0       76.0
# 2       Pyrénées-Atlantiques          FRA     France      183.0       76.0
# 3                      Paris          FRA     France      168.0       64.0
# 4                    England          GBR     France        NaN        NaN
# ...                      ...          ...        ...        ...        ...
# 145495            Sverdlovsk          RUS        ROC      167.0       61.0
# 145496                Moskva          RUS        ROC      168.0       65.0
# 145497           Arkhangelsk          RUS        ROC      163.0       55.0
# 145498           Deux-Sèvres          FRA     France      166.0        NaN
# 145499       New South Wales          AUS  Australia        NaN        NaN
#
#          died_date
# 0       1960-10-02
# 1              NaN
# 2       1994-07-17
# 3       1978-03-20
# 4       1930-07-25
# ...            ...
# 145495         NaN
# 145496         NaN
# 145497         NaN
# 145498  1986-03-18
# 145499  2003-10-20
#
# [145500 rows x 10 columns]

# %%
data1['born_date_time']=pd.to_datetime(data1['born_date'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'born_date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 data1['born_date_time']=pd.to_datetime(data1['born_date'])
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'born_date'

# %%
data['born_date']
# Out:
# 0         1886-12-12
# 1         1969-04-01
# 2         1898-08-13
# 3         1895-05-11
# 4         1878-04-17
#              ...
# 145495    2002-01-30
# 145496    1999-09-20
# 145497    1998-05-08
# 145498    1899-05-19
# 145499    1913-07-15
# Name: born_date, Length: 145500, dtype: object

# %%
data['born_date_time'] = pd.to_datetime(data['born_date'], errors='coerce')

# %%
data
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# 0                    Gironde          FRA     France        NaN        NaN
# 1                   Yvelines          FRA     France      183.0       76.0
# 2       Pyrénées-Atlantiques          FRA     France      183.0       76.0
# 3                      Paris          FRA     France      168.0       64.0
# 4                    England          GBR     France        NaN        NaN
# ...                      ...          ...        ...        ...        ...
# 145495            Sverdlovsk          RUS        ROC      167.0       61.0
# 145496                Moskva          RUS        ROC      168.0       65.0
# 145497           Arkhangelsk          RUS        ROC      163.0       55.0
# 145498           Deux-Sèvres          FRA     France      166.0        NaN
# 145499       New South Wales          AUS  Australia        NaN        NaN
#
#          died_date born_date_time
# 0       1960-10-02     1886-12-12
# 1              NaN     1969-04-01
# 2       1994-07-17     1898-08-13
# 3       1978-03-20     1895-05-11
# 4       1930-07-25     1878-04-17
# ...            ...            ...
# 145495         NaN     2002-01-30
# 145496         NaN     1999-09-20
# 145497         NaN     1998-05-08
# 145498  1986-03-18     1899-05-19
# 145499  2003-10-20     1913-07-15
#
# [145500 rows x 11 columns]

# %%
data['b_year']=data['born_date'].dt.year
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 data['year']=data['born_date'].dt.year
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/generic.py:6299, in NDFrame.__getattr__(self, name)
#    6292 if (
#    6293     name not in self._internal_names_set
#    6294     and name not in self._metadata
#    6295     and name not in self._accessors
#    6296     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297 ):
#    6298     return self[name]
# -> 6299 return object.__getattribute__(self, name)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
#     222     # we're accessing the attribute of the class, i.e., Dataset.geo
#     223     return self._accessor
# --> 224 accessor_obj = self._accessor(obj)
#     225 # Replace the property with the accessor object. Inspired by:
#     226 # https://www.pydanny.com/cached-property.html
#     227 # We need to use object.__setattr__ because we overwrite __setattr__ on
#     228 # NDFrame
#     229 object.__setattr__(obj, self._name, accessor_obj)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/indexes/accessors.py:643, in CombinedDatetimelikeProperties.__new__(cls, data)
#     640 elif isinstance(data.dtype, PeriodDtype):
#     641     return PeriodProperties(data, orig)
# --> 643 raise AttributeError("Can only use .dt accessor with datetimelike values")
#
# AttributeError: Can only use .dt accessor with datetimelike values

# %%
data['born_date'] = pd.to_datetime(data['born_date'], errors='coerce')
data['b_year'] = data['born_date'].dt.year

# %%
data
# Out:
#         athlete_id                   name  born_date        born_city  \
# 0                1  Jean-François Blanchy 1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch 1969-04-01           Meulan
# 2                3           Jean Borotra 1898-08-13         Biarritz
# 3                4        Jacques Brugnon 1895-05-11      Paris VIIIe
# 4                5           Albert Canet 1878-04-17       Wandsworth
# ...            ...                    ...        ...              ...
# 145495      149222      Polina Luchnikova 2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva 1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova 1998-05-08           Kotlas
# 145498      149225         André Foussard 1899-05-19            Niort
# 145499      149814          Bill Phillips 1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# 0                    Gironde          FRA     France        NaN        NaN
# 1                   Yvelines          FRA     France      183.0       76.0
# 2       Pyrénées-Atlantiques          FRA     France      183.0       76.0
# 3                      Paris          FRA     France      168.0       64.0
# 4                    England          GBR     France        NaN        NaN
# ...                      ...          ...        ...        ...        ...
# 145495            Sverdlovsk          RUS        ROC      167.0       61.0
# 145496                Moskva          RUS        ROC      168.0       65.0
# 145497           Arkhangelsk          RUS        ROC      163.0       55.0
# 145498           Deux-Sèvres          FRA     France      166.0        NaN
# 145499       New South Wales          AUS  Australia        NaN        NaN
#
#          died_date born_date_time  b_year
# 0       1960-10-02     1886-12-12  1886.0
# 1              NaN     1969-04-01  1969.0
# 2       1994-07-17     1898-08-13  1898.0
# 3       1978-03-20     1895-05-11  1895.0
# 4       1930-07-25     1878-04-17  1878.0
# ...            ...            ...     ...
# 145495         NaN     2002-01-30  2002.0
# 145496         NaN     1999-09-20  1999.0
# 145497         NaN     1998-05-08  1998.0
# 145498  1986-03-18     1899-05-19  1899.0
# 145499  2003-10-20     1913-07-15  1913.0
#
# [145500 rows x 12 columns]

# %%
data['born_date'] = pd.to_datetime(data['born_date'], format='%Y-%m-%d', errors='coerce')

# %%
data['born_date']
# Out:
# 0        1886-12-12
# 1        1969-04-01
# 2        1898-08-13
# 3        1895-05-11
# 4        1878-04-17
#             ...
# 145495   2002-01-30
# 145496   1999-09-20
# 145497   1998-05-08
# 145498   1899-05-19
# 145499   1913-07-15
# Name: born_date, Length: 145500, dtype: datetime64[ns]

# %%
data=pd.read_csv('bios.csv')

# %%
data
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# 0                    Gironde          FRA     France        NaN        NaN
# 1                   Yvelines          FRA     France      183.0       76.0
# 2       Pyrénées-Atlantiques          FRA     France      183.0       76.0
# 3                      Paris          FRA     France      168.0       64.0
# 4                    England          GBR     France        NaN        NaN
# ...                      ...          ...        ...        ...        ...
# 145495            Sverdlovsk          RUS        ROC      167.0       61.0
# 145496                Moskva          RUS        ROC      168.0       65.0
# 145497           Arkhangelsk          RUS        ROC      163.0       55.0
# 145498           Deux-Sèvres          FRA     France      166.0        NaN
# 145499       New South Wales          AUS  Australia        NaN        NaN
#
#          died_date
# 0       1960-10-02
# 1              NaN
# 2       1994-07-17
# 3       1978-03-20
# 4       1930-07-25
# ...            ...
# 145495         NaN
# 145496         NaN
# 145497         NaN
# 145498  1986-03-18
# 145499  2003-10-20
#
# [145500 rows x 10 columns]

# %%
data['height_category']=data['height_cm'].apply(lambda x:'Short' if x<65 else ('avg'if x<185 else 'Tail'))

# %%
data
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# 0                    Gironde          FRA     France        NaN        NaN
# 1                   Yvelines          FRA     France      183.0       76.0
# 2       Pyrénées-Atlantiques          FRA     France      183.0       76.0
# 3                      Paris          FRA     France      168.0       64.0
# 4                    England          GBR     France        NaN        NaN
# ...                      ...          ...        ...        ...        ...
# 145495            Sverdlovsk          RUS        ROC      167.0       61.0
# 145496                Moskva          RUS        ROC      168.0       65.0
# 145497           Arkhangelsk          RUS        ROC      163.0       55.0
# 145498           Deux-Sèvres          FRA     France      166.0        NaN
# 145499       New South Wales          AUS  Australia        NaN        NaN
#
#          died_date height_category
# 0       1960-10-02            Tail
# 1              NaN             avg
# 2       1994-07-17             avg
# 3       1978-03-20             avg
# 4       1930-07-25            Tail
# ...            ...             ...
# 145495         NaN             avg
# 145496         NaN             avg
# 145497         NaN             avg
# 145498  1986-03-18             avg
# 145499  2003-10-20            Tail
#
# [145500 rows x 11 columns]

# %%
def categorize_athlete(row):
    if rowl'height_cm'] < 175 and rowl'weight_kg'] < 70:
           return 'Lightweight'
    elif rowl 'height_cm'] < 185 or rowl 'weight_kg'] < 80:
          return 'Middleweight'
    else:
        return 'Heavyweight'
   data['Category'] = data.apply(categorize_athletel, axis=1)
# Out:
#   File <string>:8
#     data['Category'] = data.apply(categorize_athletel, axis=1)
#                                                               ^
# IndentationError: unindent does not match any outer indentation level

# %%
def categorize_athlete(row):
    if row['height_cm'] < 175 and row['weight_kg'] < 70:
        return 'Lightweight'
    elif row['height_cm'] < 185 or row['weight_kg'] < 80:
        return 'Middleweight'
    else:
        return 'Heavyweight'

data['Category'] = data.apply(categorize_athlete, axis=1)

# %%
data
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# 0                    Gironde          FRA     France        NaN        NaN
# 1                   Yvelines          FRA     France      183.0       76.0
# 2       Pyrénées-Atlantiques          FRA     France      183.0       76.0
# 3                      Paris          FRA     France      168.0       64.0
# 4                    England          GBR     France        NaN        NaN
# ...                      ...          ...        ...        ...        ...
# 145495            Sverdlovsk          RUS        ROC      167.0       61.0
# 145496                Moskva          RUS        ROC      168.0       65.0
# 145497           Arkhangelsk          RUS        ROC      163.0       55.0
# 145498           Deux-Sèvres          FRA     France      166.0        NaN
# 145499       New South Wales          AUS  Australia        NaN        NaN
#
#          died_date height_category      Category
# 0       1960-10-02            Tail   Heavyweight
# 1              NaN             avg  Middleweight
# 2       1994-07-17             avg  Middleweight
# 3       1978-03-20             avg   Lightweight
# 4       1930-07-25            Tail   Heavyweight
# ...            ...             ...           ...
# 145495         NaN             avg   Lightweight
# 145496         NaN             avg   Lightweight
# 145497         NaN             avg   Lightweight
# 145498  1986-03-18             avg  Middleweight
# 145499  2003-10-20            Tail   Heavyweight
#
# [145500 rows x 12 columns]

# %%
# URL of the CSV file
url = "https://raw.githubusercontent.com/KeithGalli/complete-pandas-tutorial/refs/heads/master/data/noc_regions.csv"

# Read the CSV file into a DataFrame
df = pd.read_csv(url)

# Save it locally as a CSV file
df.to_csv("noc_regions.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/urllib/request.py:1319, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1318 try:
# -> 1319     h.request(req.get_method(), req.selector, req.data, headers,
#    1320               encode_chunked=req.has_header('Transfer-encoding'))
#    1321 except OSError as err: # timeout error
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/http/client.py:1338, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1337 """Send a complete request to the server."""
# -> 1338 self._send_request(method, url, body, headers, encode_chunked)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/http/client.py:1384, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1383     body = _encode(body, 'body')
# -> 1384 self.endheaders(body, encode_chunked=encode_chunked)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/http/client.py:1333, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1332     raise CannotSendHeader()
# -> 1333 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/http/client.py:1093, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1092 del self._buffer[:]
# -> 1093 self.send(msg)
#    1095 if message_body is not None:
#    1096
#    1097     # create a consistent interface to message_body
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/http/client.py:1037, in HTTPConnection.send(self, data)
#    1036 if self.auto_open:
# -> 1037     self.connect()
#    1038 else:
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/http/client.py:1479, in HTTPSConnection.connect(self)
#    1477     server_hostname = self.host
# -> 1479 self.sock = self._context.wrap_socket(self.sock,
#    1480                                       server_hostname=server_hostname)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/ssl.py:455, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     449 def wrap_socket(self, sock, server_side=False,
#     450                 do_handshake_on_connect=True,
#     451                 suppress_ragged_eofs=True,
#     452                 server_hostname=None, session=None):
#     453     # SSLSocket class handles server_hostname encoding before it calls
#     454     # ctx._wrap_socket()
# --> 455     return self.sslsocket_class._create(
#     456         sock=sock,
#     457         server_side=server_side,
#     458         do_handshake_on_connect=do_handshake_on_connect,
#     459         suppress_ragged_eofs=suppress_ragged_eofs,
#     460         server_hostname=server_hostname,
#     461         context=self,
#     462         session=session
#     463     )
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/ssl.py:1076, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1075                 raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1076             self.do_handshake()
#    1077 except:
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/ssl.py:1372, in SSLSocket.do_handshake(self, block)
#    1371         self.settimeout(None)
# -> 1372     self._sslobj.do_handshake()
#    1373 finally:
#
# SSLCertVerificationError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1028)
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# Cell In[48], line 5
#       2 url = "https://raw.githubusercontent.com/KeithGalli/complete-pandas-tutorial/refs/heads/master/data/noc_regions.csv"
#       4 # Read the CSV file into a DataFrame
# ----> 5 df = pd.read_csv(url)
#       7 # Save it locally as a CSV file
#       8 df.to_csv("noc_regions.csv", index=False)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/io/common.py:728, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     725     codecs.lookup_error(errors)
#     727 # open URLs
# --> 728 ioargs = _get_filepath_or_buffer(
#     729     path_or_buf,
#     730     encoding=encoding,
#     731     compression=compression,
#     732     mode=mode,
#     733     storage_options=storage_options,
#     734 )
#     736 handle = ioargs.filepath_or_buffer
#     737 handles: list[BaseBuffer]
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/io/common.py:384, in _get_filepath_or_buffer(filepath_or_buffer, encoding, compression, mode, storage_options)
#     382 # assuming storage_options is to be interpreted as headers
#     383 req_info = urllib.request.Request(filepath_or_buffer, headers=storage_options)
# --> 384 with urlopen(req_info) as req:
#     385     content_encoding = req.headers.get("Content-Encoding", None)
#     386     if content_encoding == "gzip":
#     387         # Override compression based on Content-Encoding header
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/io/common.py:289, in urlopen(*args, **kwargs)
#     283 """
#     284 Lazy-import wrapper for stdlib urlopen, as that imports a big chunk of
#     285 the stdlib.
#     286 """
#     287 import urllib.request
# --> 289 return urllib.request.urlopen(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/urllib/request.py:189, in urlopen(url, data, timeout, context)
#     187 else:
#     188     opener = _opener
# --> 189 return opener.open(url, data, timeout)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/urllib/request.py:489, in OpenerDirector.open(self, fullurl, data, timeout)
#     486     req = meth(req)
#     488 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 489 response = self._open(req, data)
#     491 # post-process response
#     492 meth_name = protocol+"_response"
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/urllib/request.py:506, in OpenerDirector._open(self, req, data)
#     503     return result
#     505 protocol = req.type
# --> 506 result = self._call_chain(self.handle_open, protocol, protocol +
#     507                           '_open', req)
#     508 if result:
#     509     return result
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/urllib/request.py:466, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     464 for handler in handlers:
#     465     func = getattr(handler, meth_name)
# --> 466     result = func(*args)
#     467     if result is not None:
#     468         return result
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/urllib/request.py:1367, in HTTPSHandler.https_open(self, req)
#    1366 def https_open(self, req):
# -> 1367     return self.do_open(http.client.HTTPSConnection, req,
#    1368                         context=self._context)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/urllib/request.py:1322, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1319         h.request(req.get_method(), req.selector, req.data, headers,
#    1320                   encode_chunked=req.has_header('Transfer-encoding'))
#    1321     except OSError as err: # timeout error
# -> 1322         raise URLError(err)
#    1323     r = h.getresponse()
#    1324 except:
#
# URLError: <urlopen error [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1028)>

# %%
url = "https://raw.githubusercontent.com/KeithGalli/complete-pandas-tutorial/refs/heads/master/data/noc_regions.csv"

df = pd.read_csv(url, verify_ssl=False)
df.to_csv("noc_regions.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[49], line 3
#       1 url = "https://raw.githubusercontent.com/KeithGalli/complete-pandas-tutorial/refs/heads/master/data/noc_regions.csv"
# ----> 3 df = pd.read_csv(url, verify_ssl=False)
#       4 df.to_csv("noc_regions.csv", index=False)
#
# TypeError: read_csv() got an unexpected keyword argument 'verify_ssl'

# %%
import pandas as pd
import requests
from io import StringIO

# URL of the CSV file
url = "https://raw.githubusercontent.com/KeithGalli/complete-pandas-tutorial/master/data/noc_regions.csv"

# Fetch data while disabling SSL verification (not recommended for sensitive data)
response = requests.get(url, verify=False)

# Convert to pandas DataFrame
df = pd.read_csv(StringIO(response.text))

# Save it locally
df.to_csv("noc_regions.csv", index=False)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'raw.githubusercontent.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(

# %%
df
# Out:
#      NOC       region                 notes
# 0    AFG  Afghanistan                   NaN
# 1    AHO      Curacao  Netherlands Antilles
# 2    ALB      Albania                   NaN
# 3    ALG      Algeria                   NaN
# 4    AND      Andorra                   NaN
# ..   ...          ...                   ...
# 225  YEM        Yemen                   NaN
# 226  YMD        Yemen           South Yemen
# 227  YUG       Serbia            Yugoslavia
# 228  ZAM       Zambia                   NaN
# 229  ZIM     Zimbabwe                   NaN
#
# [230 rows x 3 columns]

# %%
merge_with_different_columns = pd.merge(data, df, left_on='born_country', right_on='NOC', how='left')

# %%
merge_with_different_columns
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country      NOC_x  height_cm  weight_kg  \
# 0                    Gironde          FRA     France        NaN        NaN
# 1                   Yvelines          FRA     France      183.0       76.0
# 2       Pyrénées-Atlantiques          FRA     France      183.0       76.0
# 3                      Paris          FRA     France      168.0       64.0
# 4                    England          GBR     France        NaN        NaN
# ...                      ...          ...        ...        ...        ...
# 145495            Sverdlovsk          RUS        ROC      167.0       61.0
# 145496                Moskva          RUS        ROC      168.0       65.0
# 145497           Arkhangelsk          RUS        ROC      163.0       55.0
# 145498           Deux-Sèvres          FRA     France      166.0        NaN
# 145499       New South Wales          AUS  Australia        NaN        NaN
#
#          died_date height_category      Category NOC_y     region notes
# 0       1960-10-02            Tail   Heavyweight   FRA     France   NaN
# 1              NaN             avg  Middleweight   FRA     France   NaN
# 2       1994-07-17             avg  Middleweight   FRA     France   NaN
# 3       1978-03-20             avg   Lightweight   FRA     France   NaN
# 4       1930-07-25            Tail   Heavyweight   GBR         UK   NaN
# ...            ...             ...           ...   ...        ...   ...
# 145495         NaN             avg   Lightweight   RUS     Russia   NaN
# 145496         NaN             avg   Lightweight   RUS     Russia   NaN
# 145497         NaN             avg   Lightweight   RUS     Russia   NaN
# 145498  1986-03-18             avg  Middleweight   FRA     France   NaN
# 145499  2003-10-20            Tail   Heavyweight   AUS  Australia   NaN
#
# [145500 rows x 15 columns]

# %%
merged_data = pd.merge(data, df, left_on='born_country', right_on='NOC', how='left', suffixes=('_left', '_right'))

# %%
merged_data
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country   NOC_left  height_cm  weight_kg  \
# 0                    Gironde          FRA     France        NaN        NaN
# 1                   Yvelines          FRA     France      183.0       76.0
# 2       Pyrénées-Atlantiques          FRA     France      183.0       76.0
# 3                      Paris          FRA     France      168.0       64.0
# 4                    England          GBR     France        NaN        NaN
# ...                      ...          ...        ...        ...        ...
# 145495            Sverdlovsk          RUS        ROC      167.0       61.0
# 145496                Moskva          RUS        ROC      168.0       65.0
# 145497           Arkhangelsk          RUS        ROC      163.0       55.0
# 145498           Deux-Sèvres          FRA     France      166.0        NaN
# 145499       New South Wales          AUS  Australia        NaN        NaN
#
#          died_date height_category      Category NOC_right     region notes
# 0       1960-10-02            Tail   Heavyweight       FRA     France   NaN
# 1              NaN             avg  Middleweight       FRA     France   NaN
# 2       1994-07-17             avg  Middleweight       FRA     France   NaN
# 3       1978-03-20             avg   Lightweight       FRA     France   NaN
# 4       1930-07-25            Tail   Heavyweight       GBR         UK   NaN
# ...            ...             ...           ...       ...        ...   ...
# 145495         NaN             avg   Lightweight       RUS     Russia   NaN
# 145496         NaN             avg   Lightweight       RUS     Russia   NaN
# 145497         NaN             avg   Lightweight       RUS     Russia   NaN
# 145498  1986-03-18             avg  Middleweight       FRA     France   NaN
# 145499  2003-10-20            Tail   Heavyweight       AUS  Australia   NaN
#
# [145500 rows x 15 columns]

# %%
merged_data.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country NOC_left  height_cm  weight_kg  \
# 0               Gironde          FRA   France        NaN        NaN
# 1              Yvelines          FRA   France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA   France      183.0       76.0
# 3                 Paris          FRA   France      168.0       64.0
# 4               England          GBR   France        NaN        NaN
#
#     died_date height_category      Category NOC_right  region notes
# 0  1960-10-02            Tail   Heavyweight       FRA  France   NaN
# 1         NaN             avg  Middleweight       FRA  France   NaN
# 2  1994-07-17             avg  Middleweight       FRA  France   NaN
# 3  1978-03-20             avg   Lightweight       FRA  France   NaN
# 4  1930-07-25            Tail   Heavyweight       GBR      UK   NaN

# %%
merge_with_different_columns[merge_with_different_columns['NOC_x'] != merge_with_different_columns['born_country_full']][['name', 'NOC_x', 'born_country_full']l
# Out:
#   Cell In[57], line 1
#     merge_with_different_columns[merge_with_different_columns['NOC_x'] != merge_with_different_columns['born_country_full']][['name', 'NOC_x', 'born_country_full']l
#                                                                                                                             ^
# SyntaxError: '[' was never closed

# %%
merge_with_different_columns[merge_with_different_columns['NOC_x'] != merge_with_different_columns['born_country']][['name', 'NOC_x', 'born_country']]
# Out:
#                          name      NOC_x born_country
# 0       Jean-François Blanchy     France          FRA
# 1              Arnaud Boetsch     France          FRA
# 2                Jean Borotra     France          FRA
# 3             Jacques Brugnon     France          FRA
# 4                Albert Canet     France          GBR
# ...                       ...        ...          ...
# 145495      Polina Luchnikova        ROC          RUS
# 145496    Valeriya Merkusheva        ROC          RUS
# 145497        Yuliya Smirnova        ROC          RUS
# 145498         André Foussard     France          FRA
# 145499          Bill Phillips  Australia          AUS
#
# [145500 rows x 3 columns]

# %%
usa = merge_with_different_columns [merge_with_different_columns ['born_country']=='USA']. copy ()
gbr = merge_with_different_columns [merge_with_different_columns ['born_country']=='GBR']. copy ()

# %%
usa
# Out:
#         athlete_id               name   born_date         born_city  \
# 54              55      Monique Javer  1967-07-22        Burlingame
# 960            964   Xóchitl Escobedo  1968-09-17       West Covina
# 961            965  Angélica Gavaldón  1973-10-03         El Centro
# 1231          1238     Bert Schneider  1897-07-01         Cleveland
# 1345          1352         Laura Berg  1975-01-06  Santa Fe Springs
# ...            ...                ...         ...               ...
# 145445      149168     Kristen Santos  1994-11-02         Fairfield
# 145446      149169   Corinne Stoddard  2001-08-15           Seattle
# 145454      149180      Anna Hoffmann  2000-03-28           Madison
# 145457      149183     Alix Wilkinson  2000-08-02     Mammoth Lakes
# 145468      149195  Justin Abdelkader  1987-02-25          Muskegon
#
#         born_region born_country          NOC_x  height_cm  weight_kg  \
# 54       California          USA  Great Britain      177.0       64.0
# 960      California          USA         Mexico      170.0       60.0
# 961      California          USA         Mexico      160.0       54.0
# 1231           Ohio          USA         Canada        NaN        NaN
# 1345     California          USA  United States      168.0       61.0
# ...             ...          ...            ...        ...        ...
# 145445  Connecticut          USA  United States        NaN        NaN
# 145446   Washington          USA  United States        NaN        NaN
# 145454    Wisconsin          USA  United States        NaN        NaN
# 145457   California          USA  United States        NaN        NaN
# 145468     Michigan          USA  United States      187.0       97.0
#
#          died_date height_category      Category NOC_y region notes
# 54             NaN             avg  Middleweight   USA    USA   NaN
# 960            NaN             avg   Lightweight   USA    USA   NaN
# 961            NaN             avg   Lightweight   USA    USA   NaN
# 1231    1986-02-20            Tail   Heavyweight   USA    USA   NaN
# 1345           NaN             avg   Lightweight   USA    USA   NaN
# ...            ...             ...           ...   ...    ...   ...
# 145445         NaN            Tail   Heavyweight   USA    USA   NaN
# 145446         NaN            Tail   Heavyweight   USA    USA   NaN
# 145454         NaN            Tail   Heavyweight   USA    USA   NaN
# 145457         NaN            Tail   Heavyweight   USA    USA   NaN
# 145468         NaN            Tail   Heavyweight   USA    USA   NaN
#
# [9641 rows x 15 columns]

# %%
gbr.head()
# Out:
#     athlete_id               name   born_date    born_city born_region  \
# 4            5       Albert Canet  1878-04-17   Wandsworth     England
# 37          38    Helen Aitchison  1881-12-06   Sunderland     England
# 38          39  Geraldine Beamish  1883-06-23  Forest Gate     England
# 39          40       Dora Boothby  1881-08-02     Finchley     England
# 40          41     Julie Bradbury  1967-02-12       Oxford     England
#
#    born_country          NOC_x  height_cm  weight_kg   died_date  \
# 4           GBR         France        NaN        NaN  1930-07-25
# 37          GBR  Great Britain        NaN        NaN  1947-05-26
# 38          GBR  Great Britain        NaN        NaN  1972-05-10
# 39          GBR  Great Britain        NaN        NaN  1970-02-22
# 40          GBR  Great Britain      175.0       64.0         NaN
#
#    height_category      Category NOC_y region notes
# 4             Tail   Heavyweight   GBR     UK   NaN
# 37            Tail   Heavyweight   GBR     UK   NaN
# 38            Tail   Heavyweight   GBR     UK   NaN
# 39            Tail   Heavyweight   GBR     UK   NaN
# 40             avg  Middleweight   GBR     UK   NaN

# %%
new_df=pd.concat([usa,gbr])

# %%
new_df
# Out:
#         athlete_id                name   born_date         born_city  \
# 54              55       Monique Javer  1967-07-22        Burlingame
# 960            964    Xóchitl Escobedo  1968-09-17       West Covina
# 961            965   Angélica Gavaldón  1973-10-03         El Centro
# 1231          1238      Bert Schneider  1897-07-01         Cleveland
# 1345          1352          Laura Berg  1975-01-06  Santa Fe Springs
# ...            ...                 ...         ...               ...
# 144811      148512  Benjamin Alexander  1983-05-08            London
# 144815      148517       Ashley Watson  1993-10-28      Peterborough
# 145005      148716     Peder Kongshaug  2001-08-13         Wimbledon
# 145319      149041          Axel Brown  1992-04-02         Harrogate
# 145388      149111      Jean-Luc Baker  1993-10-07           Burnley
#
#        born_region born_country                NOC_x  height_cm  weight_kg  \
# 54      California          USA        Great Britain      177.0       64.0
# 960     California          USA               Mexico      170.0       60.0
# 961     California          USA               Mexico      160.0       54.0
# 1231          Ohio          USA               Canada        NaN        NaN
# 1345    California          USA        United States      168.0       61.0
# ...            ...          ...                  ...        ...        ...
# 144811     England          GBR              Jamaica        NaN        NaN
# 144815     England          GBR              Jamaica        NaN        NaN
# 145005     England          GBR               Norway      184.0       86.0
# 145319     England          GBR  Trinidad and Tobago        NaN        NaN
# 145388     England          GBR        United States        NaN        NaN
#
#          died_date height_category      Category NOC_y region notes
# 54             NaN             avg  Middleweight   USA    USA   NaN
# 960            NaN             avg   Lightweight   USA    USA   NaN
# 961            NaN             avg   Lightweight   USA    USA   NaN
# 1231    1986-02-20            Tail   Heavyweight   USA    USA   NaN
# 1345           NaN             avg   Lightweight   USA    USA   NaN
# ...            ...             ...           ...   ...    ...   ...
# 144811         NaN            Tail   Heavyweight   GBR     UK   NaN
# 144815         NaN            Tail   Heavyweight   GBR     UK   NaN
# 145005         NaN             avg  Middleweight   GBR     UK   NaN
# 145319         NaN            Tail   Heavyweight   GBR     UK   NaN
# 145388         NaN            Tail   Heavyweight   GBR     UK   NaN
#
# [15433 rows x 15 columns]

# %%
import numpy as np
new_df.loc[[0:1000],'height_cm']=np.nan
# Out:
#   Cell In[71], line 2
#     new_df.loc[[0:1000],'height_cm']=np.nan
#                  ^
# SyntaxError: invalid syntax

# %%
import numpy as np
new_df.loc[[54,960],'height_cm']=np.nan

# %%
new_df
# Out:
#         athlete_id                name   born_date         born_city  \
# 54              55       Monique Javer  1967-07-22        Burlingame
# 960            964    Xóchitl Escobedo  1968-09-17       West Covina
# 961            965   Angélica Gavaldón  1973-10-03         El Centro
# 1231          1238      Bert Schneider  1897-07-01         Cleveland
# 1345          1352          Laura Berg  1975-01-06  Santa Fe Springs
# ...            ...                 ...         ...               ...
# 144811      148512  Benjamin Alexander  1983-05-08            London
# 144815      148517       Ashley Watson  1993-10-28      Peterborough
# 145005      148716     Peder Kongshaug  2001-08-13         Wimbledon
# 145319      149041          Axel Brown  1992-04-02         Harrogate
# 145388      149111      Jean-Luc Baker  1993-10-07           Burnley
#
#        born_region born_country                NOC_x  height_cm  weight_kg  \
# 54      California          USA        Great Britain        NaN       64.0
# 960     California          USA               Mexico        NaN       60.0
# 961     California          USA               Mexico      160.0       54.0
# 1231          Ohio          USA               Canada        NaN        NaN
# 1345    California          USA        United States      168.0       61.0
# ...            ...          ...                  ...        ...        ...
# 144811     England          GBR              Jamaica        NaN        NaN
# 144815     England          GBR              Jamaica        NaN        NaN
# 145005     England          GBR               Norway      184.0       86.0
# 145319     England          GBR  Trinidad and Tobago        NaN        NaN
# 145388     England          GBR        United States        NaN        NaN
#
#          died_date height_category      Category NOC_y region notes
# 54             NaN             avg  Middleweight   USA    USA   NaN
# 960            NaN             avg   Lightweight   USA    USA   NaN
# 961            NaN             avg   Lightweight   USA    USA   NaN
# 1231    1986-02-20            Tail   Heavyweight   USA    USA   NaN
# 1345           NaN             avg   Lightweight   USA    USA   NaN
# ...            ...             ...           ...   ...    ...   ...
# 144811         NaN            Tail   Heavyweight   GBR     UK   NaN
# 144815         NaN            Tail   Heavyweight   GBR     UK   NaN
# 145005         NaN             avg  Middleweight   GBR     UK   NaN
# 145319         NaN            Tail   Heavyweight   GBR     UK   NaN
# 145388         NaN            Tail   Heavyweight   GBR     UK   NaN
#
# [15433 rows x 15 columns]

# %%
df_filled = new_df.fillna(new_df['weight_kg'].interpolate())

# %%
df_filled
# Out:
#         athlete_id                name   born_date         born_city  \
# 54              55       Monique Javer  1967-07-22        Burlingame
# 960            964    Xóchitl Escobedo  1968-09-17       West Covina
# 961            965   Angélica Gavaldón  1973-10-03         El Centro
# 1231          1238      Bert Schneider  1897-07-01         Cleveland
# 1345          1352          Laura Berg  1975-01-06  Santa Fe Springs
# ...            ...                 ...         ...               ...
# 144811      148512  Benjamin Alexander  1983-05-08            London
# 144815      148517       Ashley Watson  1993-10-28      Peterborough
# 145005      148716     Peder Kongshaug  2001-08-13         Wimbledon
# 145319      149041          Axel Brown  1992-04-02         Harrogate
# 145388      149111      Jean-Luc Baker  1993-10-07           Burnley
#
#        born_region born_country                NOC_x  height_cm  weight_kg  \
# 54      California          USA        Great Britain        NaN       64.0
# 960     California          USA               Mexico        NaN       60.0
# 961     California          USA               Mexico      160.0       54.0
# 1231          Ohio          USA               Canada        NaN        NaN
# 1345    California          USA        United States      168.0       61.0
# ...            ...          ...                  ...        ...        ...
# 144811     England          GBR              Jamaica        NaN        NaN
# 144815     England          GBR              Jamaica        NaN        NaN
# 145005     England          GBR               Norway      184.0       86.0
# 145319     England          GBR  Trinidad and Tobago        NaN        NaN
# 145388     England          GBR        United States        NaN        NaN
#
#          died_date height_category      Category NOC_y region notes
# 54             NaN             avg  Middleweight   USA    USA   NaN
# 960            NaN             avg   Lightweight   USA    USA   NaN
# 961            NaN             avg   Lightweight   USA    USA   NaN
# 1231    1986-02-20            Tail   Heavyweight   USA    USA   NaN
# 1345           NaN             avg   Lightweight   USA    USA   NaN
# ...            ...             ...           ...   ...    ...   ...
# 144811         NaN            Tail   Heavyweight   GBR     UK   NaN
# 144815         NaN            Tail   Heavyweight   GBR     UK   NaN
# 145005         NaN             avg  Middleweight   GBR     UK   NaN
# 145319         NaN            Tail   Heavyweight   GBR     UK   NaN
# 145388         NaN            Tail   Heavyweight   GBR     UK   NaN
#
# [15433 rows x 15 columns]

# %%
new_df['weight_kg'].interpolate()
# Out:
# 54        64.000000
# 960       60.000000
# 961       54.000000
# 1231      57.500000
# 1345      61.000000
#             ...
# 144811    86.068966
# 144815    86.034483
# 145005    86.000000
# 145319    86.000000
# 145388    86.000000
# Name: weight_kg, Length: 15433, dtype: float64

# %%
new_df
# Out:
#         athlete_id                name   born_date         born_city  \
# 54              55       Monique Javer  1967-07-22        Burlingame
# 960            964    Xóchitl Escobedo  1968-09-17       West Covina
# 961            965   Angélica Gavaldón  1973-10-03         El Centro
# 1231          1238      Bert Schneider  1897-07-01         Cleveland
# 1345          1352          Laura Berg  1975-01-06  Santa Fe Springs
# ...            ...                 ...         ...               ...
# 144811      148512  Benjamin Alexander  1983-05-08            London
# 144815      148517       Ashley Watson  1993-10-28      Peterborough
# 145005      148716     Peder Kongshaug  2001-08-13         Wimbledon
# 145319      149041          Axel Brown  1992-04-02         Harrogate
# 145388      149111      Jean-Luc Baker  1993-10-07           Burnley
#
#        born_region born_country                NOC_x  height_cm  weight_kg  \
# 54      California          USA        Great Britain        NaN       64.0
# 960     California          USA               Mexico        NaN       60.0
# 961     California          USA               Mexico      160.0       54.0
# 1231          Ohio          USA               Canada        NaN        NaN
# 1345    California          USA        United States      168.0       61.0
# ...            ...          ...                  ...        ...        ...
# 144811     England          GBR              Jamaica        NaN        NaN
# 144815     England          GBR              Jamaica        NaN        NaN
# 145005     England          GBR               Norway      184.0       86.0
# 145319     England          GBR  Trinidad and Tobago        NaN        NaN
# 145388     England          GBR        United States        NaN        NaN
#
#          died_date height_category      Category NOC_y region notes
# 54             NaN             avg  Middleweight   USA    USA   NaN
# 960            NaN             avg   Lightweight   USA    USA   NaN
# 961            NaN             avg   Lightweight   USA    USA   NaN
# 1231    1986-02-20            Tail   Heavyweight   USA    USA   NaN
# 1345           NaN             avg   Lightweight   USA    USA   NaN
# ...            ...             ...           ...   ...    ...   ...
# 144811         NaN            Tail   Heavyweight   GBR     UK   NaN
# 144815         NaN            Tail   Heavyweight   GBR     UK   NaN
# 145005         NaN             avg  Middleweight   GBR     UK   NaN
# 145319         NaN            Tail   Heavyweight   GBR     UK   NaN
# 145388         NaN            Tail   Heavyweight   GBR     UK   NaN
#
# [15433 rows x 15 columns]

# %%
new_df.value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
new_df['weight_kg'].value_counts()
# Out:
# weight_kg
# 70.0     486
# 75.0     449
# 73.0     427
# 68.0     427
# 77.0     395
#         ...
# 148.0      1
# 152.0      1
# 37.0       1
# 39.0       1
# 160.0      1
# Name: count, Length: 120, dtype: int64

# %%
new_df['weight_kg'].value_counts().head()
# Out:
# weight_kg
# 70.0    486
# 75.0    449
# 73.0    427
# 68.0    427
# 77.0    395
# Name: count, dtype: int64

# %%
new_df['born_city'].value_counts().head()
# Out:
# born_city
# New York        416
# London          317
# Chicago         283
# Los Angeles     230
# Philadelphia    205
# Name: count, dtype: int64

# %%
url='https://raw.githubusercontent.com/KeithGalli/complete-pandas-tutorial/refs/heads/master/warmup-data/coffee.csv'
response = requests.get(url, verify=False)

# Convert to pandas DataFrame
df = pd.read_csv(StringIO(response.text))
df.to_csv("coffee.csv", index=False)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'raw.githubusercontent.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(

# %%
df
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
df.groupby(['Coffee Type'])['Units Sold'].sum()
# Out:
# Coffee Type
# Espresso    265
# Latte       195
# Name: Units Sold, dtype: int64

# %%
df.groupby(['Coffee Type'])['Units Sold'].mean()
# Out:
# Coffee Type
# Espresso    37.857143
# Latte       27.857143
# Name: Units Sold, dtype: float64

# %%
df.groupby(['Coffee Type']).agg({'Units Sold':'sum'})
# Out:
#              Units Sold
# Coffee Type
# Espresso            265
# Latte               195

# %%
df.groupby(['Coffee Type']).agg({'Units Sold':'sum', 'Units Sold':'mean'})
# Out:
#              Units Sold
# Coffee Type
# Espresso      37.857143
# Latte         27.857143

# %%
df
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
pivot_df = df.pivot(index='Day', columns='Coffee Type', values='revenue')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'revenue'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[94], line 1
# ----> 1 pivot_df = df.pivot(index='Day', columns='Coffee Type', values='revenue')
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/frame.py:9339, in DataFrame.pivot(self, columns, index, values)
#    9332 @Substitution("")
#    9333 @Appender(_shared_docs["pivot"])
#    9334 def pivot(
#    9335     self, *, columns, index=lib.no_default, values=lib.no_default
#    9336 ) -> DataFrame:
#    9337     from pandas.core.reshape.pivot import pivot
# -> 9339     return pivot(self, index=index, columns=columns, values=values)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/reshape/pivot.py:566, in pivot(data, columns, index, values)
#     562         indexed = data._constructor(
#     563             data[values]._values, index=multiindex, columns=values
#     564         )
#     565     else:
# --> 566         indexed = data._constructor_sliced(data[values]._values, index=multiindex)
#     567 # error: Argument 1 to "unstack" of "DataFrame" has incompatible type "Union
#     568 # [List[Any], ExtensionArray, ndarray[Any, Any], Index, Series]"; expected
#     569 # "Hashable"
#     570 result = indexed.unstack(columns_listlike)  # type: ignore[arg-type]
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'revenue'

# %%
pivot_df = df.pivot(index='Day', columns='Coffee Type', values='revenue')

# %%
pivot_df = df.pivot_table(index='Day', columns='Coffee Type', values='revenue', aggfunc='sum')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[95], line 1
# ----> 1 pivot_df = df.pivot_table(index='Day', columns='Coffee Type', values='revenue', aggfunc='sum')
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/frame.py:9509, in DataFrame.pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#    9492 @Substitution("")
#    9493 @Appender(_shared_docs["pivot_table"])
#    9494 def pivot_table(
#    (...)
#    9505     sort: bool = True,
#    9506 ) -> DataFrame:
#    9507     from pandas.core.reshape.pivot import pivot_table
# -> 9509     return pivot_table(
#    9510         self,
#    9511         values=values,
#    9512         index=index,
#    9513         columns=columns,
#    9514         aggfunc=aggfunc,
#    9515         fill_value=fill_value,
#    9516         margins=margins,
#    9517         dropna=dropna,
#    9518         margins_name=margins_name,
#    9519         observed=observed,
#    9520         sort=sort,
#    9521     )
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/reshape/pivot.py:102, in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#      99     table = concat(pieces, keys=keys, axis=1)
#     100     return table.__finalize__(data, method="pivot_table")
# --> 102 table = __internal_pivot_table(
#     103     data,
#     104     values,
#     105     index,
#     106     columns,
#     107     aggfunc,
#     108     fill_value,
#     109     margins,
#     110     dropna,
#     111     margins_name,
#     112     observed,
#     113     sort,
#     114 )
#     115 return table.__finalize__(data, method="pivot_table")
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/reshape/pivot.py:148, in __internal_pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#     146 for i in values:
#     147     if i not in data:
# --> 148         raise KeyError(i)
#     150 to_filter = []
#     151 for x in keys + values:
#
# KeyError: 'revenue'

# %%
df = df.dropna(subset=['revenue'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/tx/8b5nnqtj2pq8dp4pn18b_6rm0000gn/T/ipykernel_55349/3761096438.py in ?()
# ----> 1 df = df.dropna(subset=['revenue'])
#
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/frame.py in ?(self, axis, how, thresh, subset, inplace, ignore_index)
#    6666             ax = self._get_axis(agg_axis)
#    6667             indices = ax.get_indexer_for(subset)
#    6668             check = indices == -1
#    6669             if check.any():
# -> 6670                 raise KeyError(np.array(subset)[check].tolist())
#    6671             agg_obj = self.take(indices, axis=agg_axis)
#    6672
#    6673         if thresh is not lib.no_default:
#
# KeyError: ['revenue']

# %%
df = df.dropna(subset=['revenue'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/tx/8b5nnqtj2pq8dp4pn18b_6rm0000gn/T/ipykernel_55349/698817248.py in ?()
# ----> 1 df = df.dropna(subset=['revenue'])
#
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/frame.py in ?(self, axis, how, thresh, subset, inplace, ignore_index)
#    6666             ax = self._get_axis(agg_axis)
#    6667             indices = ax.get_indexer_for(subset)
#    6668             check = indices == -1
#    6669             if check.any():
# -> 6670                 raise KeyError(np.array(subset)[check].tolist())
#    6671             agg_obj = self.take(indices, axis=agg_axis)
#    6672
#    6673         if thresh is not lib.no_default:
#
# KeyError: ['revenue']

# %%
df
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
pivot_df = df.pivot(index='Day', columns='Coffee Type', values='Units Sold')

# %%
pivot_df
# Out:
# Coffee Type  Espresso  Latte
# Day
# Friday             45     35
# Monday             25     15
# Saturday           45     35
# Sunday             45     35
# Thursday           40     30
# Tuesday            30     20
# Wednesday          35     25

# %%
pivot_df.sum()
# Out:
# Coffee Type
# Espresso    265
# Latte       195
# dtype: int64

# %%
pivot_df.sum(axis=1)
# Out:
# Day
# Friday       80
# Monday       40
# Saturday     80
# Sunday       80
# Thursday     70
# Tuesday      50
# Wednesday    60
# dtype: int64

# %%
pivot_df.sum(axis=1)
# Out:
# Day
# Friday       80
# Monday       40
# Saturday     80
# Sunday       80
# Thursday     70
# Tuesday      50
# Wednesday    60
# dtype: int64

# %%
pivot_df.sort_values(axis=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[108], line 1
# ----> 1 pivot_df.sort_values(axis=1)
#
# TypeError: DataFrame.sort_values() missing 1 required positional argument: 'by'

# %%
df
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
bios=pd.read_csv('bios.csv')

# %%
bios
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# 0                    Gironde          FRA     France        NaN        NaN
# 1                   Yvelines          FRA     France      183.0       76.0
# 2       Pyrénées-Atlantiques          FRA     France      183.0       76.0
# 3                      Paris          FRA     France      168.0       64.0
# 4                    England          GBR     France        NaN        NaN
# ...                      ...          ...        ...        ...        ...
# 145495            Sverdlovsk          RUS        ROC      167.0       61.0
# 145496                Moskva          RUS        ROC      168.0       65.0
# 145497           Arkhangelsk          RUS        ROC      163.0       55.0
# 145498           Deux-Sèvres          FRA     France      166.0        NaN
# 145499       New South Wales          AUS  Australia        NaN        NaN
#
#          died_date
# 0       1960-10-02
# 1              NaN
# 2       1994-07-17
# 3       1978-03-20
# 4       1930-07-25
# ...            ...
# 145495         NaN
# 145496         NaN
# 145497         NaN
# 145498  1986-03-18
# 145499  2003-10-20
#
# [145500 rows x 10 columns]

# %%
bios ['born_date'] = pd. to_datetime(bios ['born_date'])
bios ['month_born'] = bios['born_date'].dt.month
bios ['year_born'] = bios['born_date'].dt.year

# %%
bios
# Out:
#         athlete_id                   name  born_date        born_city  \
# 0                1  Jean-François Blanchy 1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch 1969-04-01           Meulan
# 2                3           Jean Borotra 1898-08-13         Biarritz
# 3                4        Jacques Brugnon 1895-05-11      Paris VIIIe
# 4                5           Albert Canet 1878-04-17       Wandsworth
# ...            ...                    ...        ...              ...
# 145495      149222      Polina Luchnikova 2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva 1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova 1998-05-08           Kotlas
# 145498      149225         André Foussard 1899-05-19            Niort
# 145499      149814          Bill Phillips 1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# 0                    Gironde          FRA     France        NaN        NaN
# 1                   Yvelines          FRA     France      183.0       76.0
# 2       Pyrénées-Atlantiques          FRA     France      183.0       76.0
# 3                      Paris          FRA     France      168.0       64.0
# 4                    England          GBR     France        NaN        NaN
# ...                      ...          ...        ...        ...        ...
# 145495            Sverdlovsk          RUS        ROC      167.0       61.0
# 145496                Moskva          RUS        ROC      168.0       65.0
# 145497           Arkhangelsk          RUS        ROC      163.0       55.0
# 145498           Deux-Sèvres          FRA     France      166.0        NaN
# 145499       New South Wales          AUS  Australia        NaN        NaN
#
#          died_date  month_born  year_born
# 0       1960-10-02        12.0     1886.0
# 1              NaN         4.0     1969.0
# 2       1994-07-17         8.0     1898.0
# 3       1978-03-20         5.0     1895.0
# 4       1930-07-25         4.0     1878.0
# ...            ...         ...        ...
# 145495         NaN         1.0     2002.0
# 145496         NaN         9.0     1999.0
# 145497         NaN         5.0     1998.0
# 145498  1986-03-18         5.0     1899.0
# 145499  2003-10-20         7.0     1913.0
#
# [145500 rows x 12 columns]

# %%
bios['weight_kg1']=bios['weight_kg'].shift(2)

# %%
bios
# Out:
#         athlete_id                   name  born_date        born_city  \
# 0                1  Jean-François Blanchy 1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch 1969-04-01           Meulan
# 2                3           Jean Borotra 1898-08-13         Biarritz
# 3                4        Jacques Brugnon 1895-05-11      Paris VIIIe
# 4                5           Albert Canet 1878-04-17       Wandsworth
# ...            ...                    ...        ...              ...
# 145495      149222      Polina Luchnikova 2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva 1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova 1998-05-08           Kotlas
# 145498      149225         André Foussard 1899-05-19            Niort
# 145499      149814          Bill Phillips 1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# 0                    Gironde          FRA     France        NaN        NaN
# 1                   Yvelines          FRA     France      183.0       76.0
# 2       Pyrénées-Atlantiques          FRA     France      183.0       76.0
# 3                      Paris          FRA     France      168.0       64.0
# 4                    England          GBR     France        NaN        NaN
# ...                      ...          ...        ...        ...        ...
# 145495            Sverdlovsk          RUS        ROC      167.0       61.0
# 145496                Moskva          RUS        ROC      168.0       65.0
# 145497           Arkhangelsk          RUS        ROC      163.0       55.0
# 145498           Deux-Sèvres          FRA     France      166.0        NaN
# 145499       New South Wales          AUS  Australia        NaN        NaN
#
#          died_date  month_born  year_born  weight_kg1
# 0       1960-10-02        12.0     1886.0         NaN
# 1              NaN         4.0     1969.0         NaN
# 2       1994-07-17         8.0     1898.0         NaN
# 3       1978-03-20         5.0     1895.0        76.0
# 4       1930-07-25         4.0     1878.0        76.0
# ...            ...         ...        ...         ...
# 145495         NaN         1.0     2002.0         NaN
# 145496         NaN         9.0     1999.0         NaN
# 145497         NaN         5.0     1998.0        61.0
# 145498  1986-03-18         5.0     1899.0        65.0
# 145499  2003-10-20         7.0     1913.0        55.0
#
# [145500 rows x 13 columns]

# %%
bios['avg']=bios['weight_kg']/bios['height_cm']

# %%
bios
# Out:
#         athlete_id                   name  born_date        born_city  \
# 0                1  Jean-François Blanchy 1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch 1969-04-01           Meulan
# 2                3           Jean Borotra 1898-08-13         Biarritz
# 3                4        Jacques Brugnon 1895-05-11      Paris VIIIe
# 4                5           Albert Canet 1878-04-17       Wandsworth
# ...            ...                    ...        ...              ...
# 145495      149222      Polina Luchnikova 2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva 1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova 1998-05-08           Kotlas
# 145498      149225         André Foussard 1899-05-19            Niort
# 145499      149814          Bill Phillips 1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# 0                    Gironde          FRA     France        NaN        NaN
# 1                   Yvelines          FRA     France      183.0       76.0
# 2       Pyrénées-Atlantiques          FRA     France      183.0       76.0
# 3                      Paris          FRA     France      168.0       64.0
# 4                    England          GBR     France        NaN        NaN
# ...                      ...          ...        ...        ...        ...
# 145495            Sverdlovsk          RUS        ROC      167.0       61.0
# 145496                Moskva          RUS        ROC      168.0       65.0
# 145497           Arkhangelsk          RUS        ROC      163.0       55.0
# 145498           Deux-Sèvres          FRA     France      166.0        NaN
# 145499       New South Wales          AUS  Australia        NaN        NaN
#
#          died_date  month_born  year_born  weight_kg1       avg
# 0       1960-10-02        12.0     1886.0         NaN       NaN
# 1              NaN         4.0     1969.0         NaN  0.415301
# 2       1994-07-17         8.0     1898.0         NaN  0.415301
# 3       1978-03-20         5.0     1895.0        76.0  0.380952
# 4       1930-07-25         4.0     1878.0        76.0       NaN
# ...            ...         ...        ...         ...       ...
# 145495         NaN         1.0     2002.0         NaN  0.365269
# 145496         NaN         9.0     1999.0         NaN  0.386905
# 145497         NaN         5.0     1998.0        61.0  0.337423
# 145498  1986-03-18         5.0     1899.0        65.0       NaN
# 145499  2003-10-20         7.0     1913.0        55.0       NaN
#
# [145500 rows x 14 columns]

# %%
bios['rank']=bios['avg'].rank()

# %%
bios
# Out:
#         athlete_id                   name  born_date        born_city  \
# 0                1  Jean-François Blanchy 1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch 1969-04-01           Meulan
# 2                3           Jean Borotra 1898-08-13         Biarritz
# 3                4        Jacques Brugnon 1895-05-11      Paris VIIIe
# 4                5           Albert Canet 1878-04-17       Wandsworth
# ...            ...                    ...        ...              ...
# 145495      149222      Polina Luchnikova 2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva 1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova 1998-05-08           Kotlas
# 145498      149225         André Foussard 1899-05-19            Niort
# 145499      149814          Bill Phillips 1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# 0                    Gironde          FRA     France        NaN        NaN
# 1                   Yvelines          FRA     France      183.0       76.0
# 2       Pyrénées-Atlantiques          FRA     France      183.0       76.0
# 3                      Paris          FRA     France      168.0       64.0
# 4                    England          GBR     France        NaN        NaN
# ...                      ...          ...        ...        ...        ...
# 145495            Sverdlovsk          RUS        ROC      167.0       61.0
# 145496                Moskva          RUS        ROC      168.0       65.0
# 145497           Arkhangelsk          RUS        ROC      163.0       55.0
# 145498           Deux-Sèvres          FRA     France      166.0        NaN
# 145499       New South Wales          AUS  Australia        NaN        NaN
#
#          died_date  month_born  year_born  weight_kg1       avg     rank
# 0       1960-10-02        12.0     1886.0         NaN       NaN      NaN
# 1              NaN         4.0     1969.0         NaN  0.415301  61200.0
# 2       1994-07-17         8.0     1898.0         NaN  0.415301  61200.0
# 3       1978-03-20         5.0     1895.0        76.0  0.380952  37154.0
# 4       1930-07-25         4.0     1878.0        76.0       NaN      NaN
# ...            ...         ...        ...         ...       ...      ...
# 145495         NaN         1.0     2002.0         NaN  0.365269  27669.5
# 145496         NaN         9.0     1999.0         NaN  0.386905  41159.5
# 145497         NaN         5.0     1998.0        61.0  0.337423  13313.0
# 145498  1986-03-18         5.0     1899.0        65.0       NaN      NaN
# 145499  2003-10-20         7.0     1913.0        55.0       NaN      NaN
#
# [145500 rows x 15 columns]

# %%
bios['rank'].sort_values()
# Out:
# 126937    1.0
# 28762     2.0
# 28712     3.0
# 90795     4.0
# 28159     6.0
#          ...
# 145492    NaN
# 145493    NaN
# 145494    NaN
# 145498    NaN
# 145499    NaN
# Name: rank, Length: 145500, dtype: float64

# %%
bios.sort_values(['rank'])
# Out:
#         athlete_id                   name  born_date           born_city  \
# 126937      129348             Léia Silva 1985-03-01            Ibitinga
# 28762        28976         Choi Myong-Hui 1966-06-13                 NaN
# 28712        28926           Anita Jokiel 1966-12-02         Ruda Śląska
# 90795        91518          Kana Yamawaki 1984-09-01                Gifu
# 28159        28369        Céline Degrange 1978-12-29             Moulins
# ...            ...                    ...        ...                 ...
# 145492      149219  Carlos García-Ordóñez 1927-04-24  La Habana (Havana)
# 145493      149220     Landysh Falyakhova 1998-08-31    Dva Polya Artash
# 145494      149221          George Wright 1890-07-21             Toronto
# 145498      149225         André Foussard 1899-05-19               Niort
# 145499      149814          Bill Phillips 1913-07-15        Dulwich Hill
#
#                  born_region born_country  \
# 126937             São Paulo          BRA
# 28762                    NaN          NaN
# 28712                Śląskie          POL
# 90795                   Gifu          JPN
# 28159                 Allier          FRA
# ...                      ...          ...
# 145492   Ciudad de La Habana          CUB
# 145493  Respublika Tatarstan          RUS
# 145494               Ontario          CAN
# 145498           Deux-Sèvres          FRA
# 145499       New South Wales          AUS
#
#                                           NOC  height_cm  weight_kg  \
# 126937                                 Brazil      169.0       30.0
# 28762   Democratic People's Republic of Korea      135.0       25.0
# 28712                                  Poland      142.0       28.0
# 90795                                   Japan      141.0       28.0
# 28159                                  France      150.0       30.0
# ...                                       ...        ...        ...
# 145492                                   Cuba        NaN        NaN
# 145493                                    ROC        NaN        NaN
# 145494                                 Canada      183.0        NaN
# 145498                                 France      166.0        NaN
# 145499                              Australia        NaN        NaN
#
#          died_date  month_born  year_born  weight_kg1       avg  rank
# 126937         NaN         3.0     1985.0        70.0  0.177515   1.0
# 28762          NaN         6.0     1966.0        30.0  0.185185   2.0
# 28712          NaN        12.0     1966.0        44.0  0.197183   3.0
# 90795          NaN         9.0     1984.0        66.0  0.198582   4.0
# 28159          NaN        12.0     1978.0        48.0  0.200000   6.0
# ...            ...         ...        ...         ...       ...   ...
# 145492  2019-11-24         4.0     1927.0         NaN       NaN   NaN
# 145493         NaN         8.0     1998.0         NaN       NaN   NaN
# 145494  1973-01-28         7.0     1890.0         NaN       NaN   NaN
# 145498  1986-03-18         5.0     1899.0        65.0       NaN   NaN
# 145499  2003-10-20         7.0     1913.0        55.0       NaN   NaN
#
# [145500 rows x 15 columns]

# %%
bios.sort_values(['rank'], ascending=False)
# Out:
#         athlete_id                   name  born_date  \
# 105671      106726           Dmitry Nosov 1980-04-09
# 105715      106771          Aythami Ruano 1977-06-18
# 91712        92442     Valentyn Rusliakov 1972-02-03
# 105722      106778   Leonel Wilfredo Ruiz 1975-07-27
# 59204        59630         Marek Galiński 1951-05-13
# ...            ...                    ...        ...
# 145492      149219  Carlos García-Ordóñez 1927-04-24
# 145493      149220     Landysh Falyakhova 1998-08-31
# 145494      149221          George Wright 1890-07-21
# 145498      149225         André Foussard 1899-05-19
# 145499      149814          Bill Phillips 1913-07-15
#
#                          born_city           born_region born_country  \
# 105671                       Chita      Zabaykalsky Kray          RUS
# 105715  Las Palmas de Gran Canaria            Las Palmas          ESP
# 91712                          NaN                   NaN          NaN
# 105722                         NaN                   NaN          NaN
# 59204                      Wrocław          Dolnośląskie          POL
# ...                            ...                   ...          ...
# 145492          La Habana (Havana)   Ciudad de La Habana          CUB
# 145493            Dva Polya Artash  Respublika Tatarstan          RUS
# 145494                     Toronto               Ontario          CAN
# 145498                       Niort           Deux-Sèvres          FRA
# 145499                Dulwich Hill       New South Wales          AUS
#
#                        NOC  height_cm  weight_kg   died_date  month_born  \
# 105671  Russian Federation      176.0      175.0         NaN         4.0
# 105715               Spain      200.0      198.0         NaN         6.0
# 91712              Ukraine      187.0      180.0         NaN         2.0
# 105722           Venezuela      187.0      178.0         NaN         7.0
# 59204               Poland      200.0      190.0  1999-09-28         5.0
# ...                    ...        ...        ...         ...         ...
# 145492                Cuba        NaN        NaN  2019-11-24         4.0
# 145493                 ROC        NaN        NaN         NaN         8.0
# 145494              Canada      183.0        NaN  1973-01-28         7.0
# 145498              France      166.0        NaN  1986-03-18         5.0
# 145499           Australia        NaN        NaN  2003-10-20         7.0
#
#         year_born  weight_kg1       avg      rank
# 105671     1980.0        81.0  0.994318  102070.0
# 105715     1977.0       105.0  0.990000  102069.0
# 91712      1972.0        60.0  0.962567  102068.0
# 105722     1975.0       100.0  0.951872  102067.0
# 59204      1951.0        92.0  0.950000  102066.0
# ...           ...         ...       ...       ...
# 145492     1927.0         NaN       NaN       NaN
# 145493     1998.0         NaN       NaN       NaN
# 145494     1890.0         NaN       NaN       NaN
# 145498     1899.0        65.0       NaN       NaN
# 145499     1913.0        55.0       NaN       NaN
#
# [145500 rows x 15 columns]

# %%
bios.sort_values(['rank'], ascending=False).sample(10)
# Out:
#         athlete_id               name  born_date      born_city  \
# 27404        27605   Leonid Nazarenko 1955-03-21     Gulkevichi
# 97903        98694       Marius Voigt 1962-02-20           Oslo
# 73085        73647  Dominique Béchard 1963-10-21            NaN
# 135902      139116         Bine Sever 2002-05-09            NaN
# 49668        50025   Mariya Kiselyova 1974-09-28         Samara
# 123871      126114    Stephen Jenness 1990-06-07     Lower Hutt
# 26677        26872      Gustavo Neffa 1971-11-03       Asunción
# 9416          9469  Cristina Martínez 1972-10-08  San Sebastián
# 44086        44425    Somporn On-Chim 1942-03-31            NaN
# 65958        66460       Wang Mingxia 1971-07-21            NaN
#
#            born_region born_country                         NOC  height_cm  \
# 27404   Krasnodar Kray          RUS                Soviet Union      174.0
# 97903             Oslo          NOR                      Norway      180.0
# 73085              NaN          NaN                   Mauritius      185.0
# 135902             NaN          NaN                    Slovenia        NaN
# 49668           Samara          RUS          Russian Federation      174.0
# 123871      Wellington          NZL                 New Zealand      179.0
# 26677         Asunción          PAR                    Paraguay      178.0
# 9416         Guipúzcoa          ESP                       Spain      165.0
# 44086              NaN          NaN                    Thailand      172.0
# 65958              NaN          NaN  People's Republic of China      166.0
#
#         weight_kg died_date  month_born  year_born  weight_kg1       avg  \
# 27404        69.0       NaN         3.0     1955.0        72.0  0.396552
# 97903        81.0       NaN         2.0     1962.0         NaN  0.450000
# 73085        85.0       NaN        10.0     1963.0        45.0  0.459459
# 135902        NaN       NaN         5.0     2002.0         NaN       NaN
# 49668        58.0       NaN         9.0     1974.0        49.0  0.333333
# 123871       76.0       NaN         6.0     1990.0        78.0  0.424581
# 26677        72.0       NaN        11.0     1971.0        68.0  0.404494
# 9416         55.0       NaN        10.0     1972.0        58.0  0.333333
# 44086        55.0       NaN         3.0     1942.0        67.0  0.319767
# 65958        58.0       NaN         7.0     1971.0        60.0  0.349398
#
#            rank
# 27404   48218.5
# 97903   80727.0
# 73085   84621.5
# 135902      NaN
# 49668   11507.0
# 123871  67387.0
# 26677   53558.5
# 9416    11507.0
# 44086    6992.0
# 65958   18819.5

# %%
bios.sort_values(['rank']).sample(10)
# Out:
#         athlete_id                       name  born_date  \
# 11209        11268         Carol Ann Blackman 1947-10-14
# 53834        54219                Zsolt Varga 1972-03-09
# 88577        89286      Saralee Thungthongkam 1979-06-13
# 80511        81162               Jane Goldman 1964-09-16
# 119703      121532             Karin Prinsloo 1989-12-02
# 56299        56700             Jaroslav Jokeľ 1970-04-02
# 10213        10269           Jang Yeong-Cheol 1964-06-04
# 142846      146474           Shakes Soyizwapi 1992-12-07
# 115300      116643               Jana Blahová 1984-11-22
# 5882          5907  Jean-Jacques da Conceição 1964-04-03
#
#                    born_city             born_region born_country  \
# 11209            Westminster                 England          GBR
# 53834               Budapest                Budapest          HUN
# 88577   Krung Thep (Bangkok)  Krung Thep Maha Nakhon          THA
# 80511                 Skokie                Illinois          USA
# 119703           Marble Hall                 Limpopo          RSA
# 56299                 Košice                  Košice          SVK
# 10213                    NaN                     NaN          NaN
# 142846                   NaN                     NaN          NaN
# 115300        Hradec Králové    Královéhradecký kraj          CZE
# 5882                Kinshasa                Kinshasa          COD
#
#                             NOC  height_cm  weight_kg died_date  month_born  \
# 11209                   Bermuda      163.0       56.0       NaN        10.0
# 53834                   Hungary      193.0       96.0       NaN         3.0
# 88577                  Thailand      163.0       55.0       NaN         6.0
# 80511             United States      170.0       58.0       NaN         9.0
# 119703             South Africa      183.0       70.0       NaN        12.0
# 56299   Czechoslovakia Slovakia      178.0       99.0       NaN         4.0
# 10213         Republic of Korea      179.0       83.0       NaN         6.0
# 142846             South Africa        NaN        NaN       NaN        12.0
# 115300                  Czechia      182.0       69.0       NaN        11.0
# 5882                     Angola      198.0      100.0       NaN         4.0
#
#         year_born  weight_kg1       avg     rank
# 11209      1947.0         NaN  0.343558  15978.0
# 53834      1972.0        90.0  0.497409  95014.0
# 88577      1979.0        83.0  0.337423  13313.0
# 80511      1964.0        62.0  0.341176  14801.5
# 119703     1989.0        82.0  0.382514  38653.5
# 56299      1970.0        90.0  0.556180  99908.0
# 10213      1964.0        61.0  0.463687  86192.5
# 142846     1992.0         NaN       NaN      NaN
# 115300     1984.0        65.0  0.379121  36219.5
# 5882       1964.0        82.0  0.505051  95969.0

# %%
bios.sort_values(['rank'])
# Out:
#         athlete_id                   name  born_date           born_city  \
# 126937      129348             Léia Silva 1985-03-01            Ibitinga
# 28762        28976         Choi Myong-Hui 1966-06-13                 NaN
# 28712        28926           Anita Jokiel 1966-12-02         Ruda Śląska
# 90795        91518          Kana Yamawaki 1984-09-01                Gifu
# 28159        28369        Céline Degrange 1978-12-29             Moulins
# ...            ...                    ...        ...                 ...
# 145492      149219  Carlos García-Ordóñez 1927-04-24  La Habana (Havana)
# 145493      149220     Landysh Falyakhova 1998-08-31    Dva Polya Artash
# 145494      149221          George Wright 1890-07-21             Toronto
# 145498      149225         André Foussard 1899-05-19               Niort
# 145499      149814          Bill Phillips 1913-07-15        Dulwich Hill
#
#                  born_region born_country  \
# 126937             São Paulo          BRA
# 28762                    NaN          NaN
# 28712                Śląskie          POL
# 90795                   Gifu          JPN
# 28159                 Allier          FRA
# ...                      ...          ...
# 145492   Ciudad de La Habana          CUB
# 145493  Respublika Tatarstan          RUS
# 145494               Ontario          CAN
# 145498           Deux-Sèvres          FRA
# 145499       New South Wales          AUS
#
#                                           NOC  height_cm  weight_kg  \
# 126937                                 Brazil      169.0       30.0
# 28762   Democratic People's Republic of Korea      135.0       25.0
# 28712                                  Poland      142.0       28.0
# 90795                                   Japan      141.0       28.0
# 28159                                  France      150.0       30.0
# ...                                       ...        ...        ...
# 145492                                   Cuba        NaN        NaN
# 145493                                    ROC        NaN        NaN
# 145494                                 Canada      183.0        NaN
# 145498                                 France      166.0        NaN
# 145499                              Australia        NaN        NaN
#
#          died_date  month_born  year_born  weight_kg1       avg  rank
# 126937         NaN         3.0     1985.0        70.0  0.177515   1.0
# 28762          NaN         6.0     1966.0        30.0  0.185185   2.0
# 28712          NaN        12.0     1966.0        44.0  0.197183   3.0
# 90795          NaN         9.0     1984.0        66.0  0.198582   4.0
# 28159          NaN        12.0     1978.0        48.0  0.200000   6.0
# ...            ...         ...        ...         ...       ...   ...
# 145492  2019-11-24         4.0     1927.0         NaN       NaN   NaN
# 145493         NaN         8.0     1998.0         NaN       NaN   NaN
# 145494  1973-01-28         7.0     1890.0         NaN       NaN   NaN
# 145498  1986-03-18         5.0     1899.0        65.0       NaN   NaN
# 145499  2003-10-20         7.0     1913.0        55.0       NaN   NaN
#
# [145500 rows x 15 columns]

# %%
bios.sort_values(['rank']).sample(10)
# Out:
#         athlete_id                              name  born_date  \
# 105528      106580                         Jon Riley 1978-12-29
# 20092        20235                      Walther Wirz 1936-06-20
# 85583        86264                     Peter Grütter 1942-06-30
# 2511          2523                     Nico Meerholz 1959-10-23
# 79408        80019  James, Baron Melvill van Carnbée 1867-08-11
# 907            911                     An Jae-Hyeong 1965-01-08
# 36183        36468           Johnny Algreen Petersen 1948-09-28
# 21143        21290                       Jean Radoux 1906-02-03
# 87721        88422                Ana Mirela Țermure 1975-01-13
# 86257        86944                    Sarah Wilhelmy 1980-02-02
#
#                      born_city    born_region born_country                NOC  \
# 105528               Brookline  Massachusetts          USA      United States
# 20092                    Olten      Solothurn          SUI        Switzerland
# 85583                     Bern           Bern          SUI        Switzerland
# 2511                       NaN            NaN          NaN       South Africa
# 79408     Den Haag (The Hague)   Zuid-Holland          NED        Netherlands
# 907                        NaN            NaN          NaN  Republic of Korea
# 36183   København (Copenhagen)    Hovedstaden          DEN            Denmark
# 21143       Marchienne-au-Pont        Hainaut          BEL            Belgium
# 87721               Căianu Mic           Cluj          ROU            Romania
# 86257                  Stepney        England          GBR      Great Britain
#
#         height_cm  weight_kg   died_date  month_born  year_born  weight_kg1  \
# 105528      173.0       68.0         NaN        12.0     1978.0        70.0
# 20092       175.0       73.0         NaN         6.0     1936.0        65.0
# 85583         NaN        NaN         NaN         6.0     1942.0        70.0
# 2511        186.0       78.0         NaN        10.0     1959.0         NaN
# 79408         NaN        NaN  1944-01-04         8.0     1867.0         NaN
# 907         183.0       74.0         NaN         1.0     1965.0         NaN
# 36183       189.0       85.0         NaN         9.0     1948.0        52.0
# 21143         NaN        NaN         NaN         2.0     1906.0         NaN
# 87721       175.0       63.0         NaN         1.0     1975.0        52.0
# 86257       178.0       62.0         NaN         2.0     1980.0        47.0
#
#              avg     rank
# 105528  0.393064  45324.0
# 20092   0.417143  62867.5
# 85583        NaN      NaN
# 2511    0.419355  64086.5
# 79408        NaN      NaN
# 907     0.404372  53329.0
# 36183   0.449735  80600.5
# 21143        NaN      NaN
# 87721   0.360000  24591.0
# 86257   0.348315  18253.5

# %%
bios.sort_values(['rank']).sample(10)[['year_born','rank']]
# Out:
#         year_born     rank
# 435        1963.0      NaN
# 91052      1976.0  33961.0
# 126172     1985.0  89195.5
# 101010     1969.0  97977.0
# 23435      1934.0      NaN
# 7156       1959.0  87599.5
# 6711       1934.0      NaN
# 20791      1952.0  18253.5
# 54051      1923.0      NaN
# 51334      1957.0  42080.0

# %%
coff=pd.read_csv('coffee.csv')

# %%
coff
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
coff.cumsum()
# Out:
#                                                   Day  \
# 0                                              Monday
# 1                                        MondayMonday
# 2                                 MondayMondayTuesday
# 3                          MondayMondayTuesdayTuesday
# 4                 MondayMondayTuesdayTuesdayWednesday
# 5        MondayMondayTuesdayTuesdayWednesdayWednesday
# 6   MondayMondayTuesdayTuesdayWednesdayWednesdayTh...
# 7   MondayMondayTuesdayTuesdayWednesdayWednesdayTh...
# 8   MondayMondayTuesdayTuesdayWednesdayWednesdayTh...
# 9   MondayMondayTuesdayTuesdayWednesdayWednesdayTh...
# 10  MondayMondayTuesdayTuesdayWednesdayWednesdayTh...
# 11  MondayMondayTuesdayTuesdayWednesdayWednesdayTh...
# 12  MondayMondayTuesdayTuesdayWednesdayWednesdayTh...
# 13  MondayMondayTuesdayTuesdayWednesdayWednesdayTh...
#
#                                           Coffee Type  Units Sold
# 0                                            Espresso          25
# 1                                       EspressoLatte          40
# 2                               EspressoLatteEspresso          70
# 3                          EspressoLatteEspressoLatte          90
# 4                  EspressoLatteEspressoLatteEspresso         125
# 5             EspressoLatteEspressoLatteEspressoLatte         150
# 6     EspressoLatteEspressoLatteEspressoLatteEspresso         190
# 7   EspressoLatteEspressoLatteEspressoLatteEspress...         220
# 8   EspressoLatteEspressoLatteEspressoLatteEspress...         265
# 9   EspressoLatteEspressoLatteEspressoLatteEspress...         300
# 10  EspressoLatteEspressoLatteEspressoLatteEspress...         345
# 11  EspressoLatteEspressoLatteEspressoLatteEspress...         380
# 12  EspressoLatteEspressoLatteEspressoLatteEspress...         425
# 13  EspressoLatteEspressoLatteEspressoLatteEspress...         460

# %%
coff.select_dtypes('int').cumsum()
# Out:
#     Units Sold
# 0           25
# 1           40
# 2           70
# 3           90
# 4          125
# 5          150
# 6          190
# 7          220
# 8          265
# 9          300
# 10         345
# 11         380
# 12         425
# 13         460

# %%
coff.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Day          14 non-null     object
#  1   Coffee Type  14 non-null     object
#  2   Units Sold   14 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 468.0+ bytes

# %%
la=coff[coff['Coffee Type']=="Latte"]. copy ()

# %%
la
# Out:
#           Day Coffee Type  Units Sold
# 1      Monday       Latte          15
# 3     Tuesday       Latte          20
# 5   Wednesday       Latte          25
# 7    Thursday       Latte          30
# 9      Friday       Latte          35
# 11   Saturday       Latte          35
# 13     Sunday       Latte          35

# %%
la['Units Sold'].rolling(3).sum()
# Out:
# 1       NaN
# 3       NaN
# 5      60.0
# 7      75.0
# 9      90.0
# 11    100.0
# 13    105.0
# Name: Units Sold, dtype: float64

# %%
la['3day']=la['Units Sold'].rolling(3).sum()

# %%
la
# Out:
#           Day Coffee Type  Units Sold   3day
# 1      Monday       Latte          15    NaN
# 3     Tuesday       Latte          20    NaN
# 5   Wednesday       Latte          25   60.0
# 7    Thursday       Latte          30   75.0
# 9      Friday       Latte          35   90.0
# 11   Saturday       Latte          35  100.0
# 13     Sunday       Latte          35  105.0

# %%
pd.__version__
# Out:
# '2.2.3'

# %%
https://raw.githubusercontent.com/KeithGalli/complete-pandas-tutorial/refs/heads/master/data/results.csv

# %%
url='https://raw.githubusercontent.com/KeithGalli/complete-pandas-tutorial/refs/heads/master/data/results.csv'
response = requests.get(url, verify=False)

# Convert to pandas DataFrame
results = pd.read_csv(StringIO(response.text))
df.to_csv("results.csv", index=False)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'raw.githubusercontent.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(

# %%
results
# Out:
#           year    type              discipline                          event  \
# 0       1912.0  Summer                  Tennis         Singles, Men (Olympic)
# 1       1912.0  Summer                  Tennis         Doubles, Men (Olympic)
# 2       1920.0  Summer                  Tennis         Singles, Men (Olympic)
# 3       1920.0  Summer                  Tennis       Doubles, Mixed (Olympic)
# 4       1920.0  Summer                  Tennis         Doubles, Men (Olympic)
# ...        ...     ...                     ...                            ...
# 308403  2022.0  Winter                    Luge         Singles, Men (Olympic)
# 308404  2022.0  Winter  Alpine Skiing (Skiing)        Slalom, Women (Olympic)
# 308405  2022.0  Winter  Alpine Skiing (Skiing)          Team, Mixed (Olympic)
# 308406  2022.0  Winter  Alpine Skiing (Skiing)  Giant Slalom, Women (Olympic)
# 308407  2022.0  Winter                     NaN        Slalom, Women (Olympic)
#
#                            as  athlete_id  noc             team  place   tied  \
# 0       Jean-François Blanchy           1  FRA              NaN   17.0   True
# 1       Jean-François Blanchy           1  FRA   Jean Montariol    NaN  False
# 2       Jean-François Blanchy           1  FRA              NaN   32.0   True
# 3       Jean-François Blanchy           1  FRA  Jeanne Vaussard    8.0   True
# 4       Jean-François Blanchy           1  FRA  Jacques Brugnon    4.0  False
# ...                       ...         ...  ...              ...    ...    ...
# 308403          Marián Skupek      148983  SVK              NaN   26.0  False
# 308404          Elsa Fermbäck      148984  SWE              NaN   28.0  False
# 308405          Hilma Lövblom      148985  SWE           Sweden   13.0  False
# 308406          Hilma Lövblom      148985  SWE              NaN    NaN  False
# 308407   Charlotta Säfvenberg      148986  NaN              NaN   24.0  False
#
#        medal
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# ...      ...
# 308403   NaN
# 308404   NaN
# 308405   NaN
# 308406   NaN
# 308407   NaN
#
# [308408 rows x 11 columns]

# %%
results_arrow=pd.read_csv('results.csv', engine='pyarrow', dtype_backend='pyarrow')

# %%
results_arrow
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# 0                    Gironde          FRA     France       <NA>       <NA>
# 1                   Yvelines          FRA     France      183.0       76.0
# 2       Pyrénées-Atlantiques          FRA     France      183.0       76.0
# 3                      Paris          FRA     France      168.0       64.0
# 4                    England          GBR     France       <NA>       <NA>
# ...                      ...          ...        ...        ...        ...
# 145495            Sverdlovsk          RUS        ROC      167.0       61.0
# 145496                Moskva          RUS        ROC      168.0       65.0
# 145497           Arkhangelsk          RUS        ROC      163.0       55.0
# 145498           Deux-Sèvres          FRA     France      166.0       <NA>
# 145499       New South Wales          AUS  Australia       <NA>       <NA>
#
#          died_date
# 0       1960-10-02
# 1             <NA>
# 2       1994-07-17
# 3       1978-03-20
# 4       1930-07-25
# ...            ...
# 145495        <NA>
# 145496        <NA>
# 145497        <NA>
# 145498  1986-03-18
# 145499  2003-10-20
#
# [145500 rows x 10 columns]

# %%
results.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 308408 entries, 0 to 308407
# Data columns (total 11 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   year        305807 non-null  float64
#  1   type        305807 non-null  object
#  2   discipline  308407 non-null  object
#  3   event       308408 non-null  object
#  4   as          308408 non-null  object
#  5   athlete_id  308408 non-null  int64
#  6   noc         308407 non-null  object
#  7   team        121714 non-null  object
#  8   place       283193 non-null  float64
#  9   tied        308408 non-null  bool
#  10  medal       44139 non-null   object
# dtypes: bool(1), float64(2), int64(1), object(7)
# memory usage: 23.8+ MB

# %%
results_arrow.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145500 entries, 0 to 145499
# Data columns (total 10 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   athlete_id    145500 non-null  int64[pyarrow]
#  1   name          145500 non-null  string[pyarrow]
#  2   born_date     143693 non-null  date32[day][pyarrow]
#  3   born_city     110908 non-null  string[pyarrow]
#  4   born_region   110908 non-null  string[pyarrow]
#  5   born_country  110908 non-null  string[pyarrow]
#  6   NOC           145499 non-null  string[pyarrow]
#  7   height_cm     106651 non-null  double[pyarrow]
#  8   weight_kg     102070 non-null  double[pyarrow]
#  9   died_date     33940 non-null   date32[day][pyarrow]
# dtypes: date32[day][pyarrow](2), double[pyarrow](2), int64[pyarrow](1), string[pyarrow](5)
# memory usage: 13.0 MB

# %%
results["as"].str.contains('Keith')
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 308403    False
# 308404    False
# 308405    False
# 308406    False
# 308407    False
# Name: as, Length: 308408, dtype: bool

# %%
results_arrow["as"].str.contains('Keith')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'as'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[156], line 1
# ----> 1 results_arrow["as"].str.contains('Keith')
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'as'
